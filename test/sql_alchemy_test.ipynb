# %%
# -*- encoding:utf-8 -*-

from sqlalchemy import (Column, String, Text, ForeignKey, \
                create_engine, MetaData, DECIMAL, DATETIME, exc, event, Index)
from sqlalchemy.schema import UniqueConstraint
from sqlalchemy.orm import (sessionmaker, relationship, scoped_session)
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.dialects.mysql import INTEGER as Integer
from datetime import datetime
import os

username = os.getenv('DB_USER_NAME')
password=os.getenv('DB_PASSWORD')
host=os.getenv('DB_HOST')
port='3306'
database=os.getenv('DB_NAME')
db_url = f"mysql+mysqlconnector://{username}:{password}@{host}:{port}/{database}"

# DB接続するためのEngineインスタンス
engine = create_engine(db_url, echo=False)

Session = scoped_session(sessionmaker(autocommit=False, autoflush=False, bind=engine))

metadata = MetaData()
Base = declarative_base()
# Out:
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_36832\3633494818.py:26: MovedIn20Warning: The ``declarative_base()`` function is now available as sqlalchemy.orm.declarative_base(). (deprecated since: 2.0) (Background on SQLAlchemy 2.0 at: https://sqlalche.me/e/b8d9)
#   Base = declarative_base()

# %%
from sqlalchemy import Column, Integer, create_engine, MetaData, DATETIME, String,Date
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import sessionmaker
from datetime import datetime
from pathlib import Path
import os
import datetime 
import pandas as pd

# %%
class Schedule(Base):
    __tablename__ = "schedule"  # テーブル名を指定
    __table_args__ = {"mysql_engine": "InnoDB"}

    schedule_id = Column('id',Integer, primary_key=True, autoincrement=True)
    prefecture = Column('都道府県',String(255))
    coverage_date = Column('イベント日',Date, nullable=False)
    day_of_week = Column('曜日',String(1), nullable=False)
    parlor_name = Column('店舗名',String(255), nullable=False)
    coverage_name = Column('取材名',String(255), nullable=False)
    medium_name = Column('媒体名',String(255))
    schedule_rank = Column('取材ランク',String(1))
    created = Column("取得時間", DATETIME, default=datetime.datetime.now, nullable=False)
    def __init__(self):
        now = datetime.datetime.now()
        self.created = now

    def record_detail(self):  # フルネームを返すメソッド
        return f"{self.coverage_date} {self.parlor_name} {self.coverage_name} "

Base.metadata.create_all(bind=engine)

# %%
from sqlalchemy.orm import sessionmaker
SessionClass = sessionmaker(engine)
session = SessionClass()

# %%
df = pd.read_csv(r'csv\test.csv')
df
# Out:
#    都道府県       イベント日 曜日             店舗名        取材名            媒体名 取材ランク
# 0   石川県  2023-03-14  火       クァトロブーム金沢  chiiips取材  ChiiiPS(チップス)     ・
# 1   石川県  2023-03-14  火  DSG WORLD 御経塚店  chiiips取材  ChiiiPS(チップス)     ・
# 2   石川県  2023-03-14  火     DSGアリーナ野々市店  chiiips取材  ChiiiPS(チップス)     ・
# 3   石川県  2023-03-14  火  DSG MEGA WORLD  chiiips取材  ChiiiPS(チップス)     ・
# 4   石川県  2023-03-15  水   DSG MEGA CITY  chiiips取材  ChiiiPS(チップス)     ・
# 5   石川県  2023-03-15  水     DSGアリーナ 七尾店  chiiips取材  ChiiiPS(チップス)     ・
# 6   石川県  2023-03-15  水        ホームラン金沢店  chiiips取材  ChiiiPS(チップス)     ・
# 7   石川県  2023-03-15  水   ホームランGOGO野々市店  chiiips取材  ChiiiPS(チップス)     ・
# 8   石川県  2023-03-16  木  DSG WORLD 御経塚店  chiiips取材  ChiiiPS(チップス)     ・
# 9   石川県  2023-03-16  木  DSG MEGA WORLD  chiiips取材  ChiiiPS(チップス)     ・
# 10  石川県  2023-03-16  木       APOLLO長田店  chiiips取材  ChiiiPS(チップス)     ・

# %%
for i,row in df.iterrows():
    schedule = Schedule()
    print(i,row)
    schedule.prefecture = row['都道府県']
    schedule.coverage_date = row['イベント日']
    schedule.day_of_week = row['曜日']
    schedule.parlor_name = row['店舗名']
    schedule.coverage_name = row['取材名']
    schedule.medium_name = row['媒体名']
    schedule.schedule_rank = row['取材ランク']
    session.add(schedule)
    session.commit()
# Out:
# 0 都道府県               石川県
# イベント日       2023-03-14
# 曜日                   火
# 店舗名          クァトロブーム金沢
# 取材名          chiiips取材
# 媒体名      ChiiiPS(チップス)
# 取材ランク                ・
# Name: 0, dtype: object
# 1 都道府県                石川県
# イベント日        2023-03-14
# 曜日                    火
# 店舗名      DSG WORLD 御経塚店
# 取材名           chiiips取材
# 媒体名       ChiiiPS(チップス)
# 取材ランク                 ・
# Name: 1, dtype: object
# 2 都道府県               石川県
# イベント日       2023-03-14
# 曜日                   火
# 店舗名        DSGアリーナ野々市店
# 取材名          chiiips取材
# 媒体名      ChiiiPS(チップス)
# 取材ランク                ・
# Name: 2, dtype: object
# 3 都道府県                石川県
# イベント日        2023-03-14
# 曜日                    火
# 店舗名      DSG MEGA WORLD
# 取材名           chiiips取材
# 媒体名       ChiiiPS(チップス)
# 取材ランク                 ・
# Name: 3, dtype: object
# 4 都道府県               石川県
# イベント日       2023-03-15
# 曜日                   水
# 店舗名      DSG MEGA CITY
# 取材名          chiiips取材
# 媒体名      ChiiiPS(チップス)
# 取材ランク                ・
# Name: 4, dtype: object
# 5 都道府県               石川県
# イベント日       2023-03-15
# 曜日                   水
# 店舗名        DSGアリーナ 七尾店
# 取材名          chiiips取材
# 媒体名      ChiiiPS(チップス)
# 取材ランク                ・
# Name: 5, dtype: object
# 6 都道府県               石川県
# イベント日       2023-03-15
# 曜日                   水
# 店舗名           ホームラン金沢店
# 取材名          chiiips取材
# 媒体名      ChiiiPS(チップス)
# 取材ランク                ・
# Name: 6, dtype: object
# 7 都道府県               石川県
# イベント日       2023-03-15
# 曜日                   水
# 店舗名      ホームランGOGO野々市店
# 取材名          chiiips取材
# 媒体名      ChiiiPS(チップス)
# 取材ランク                ・
# Name: 7, dtype: object
# 8 都道府県                石川県
# イベント日        2023-03-16
# 曜日                    木
# 店舗名      DSG WORLD 御経塚店
# 取材名           chiiips取材
# 媒体名       ChiiiPS(チップス)
# 取材ランク                 ・
# Name: 8, dtype: object
# 9 都道府県                石川県
# イベント日        2023-03-16
# 曜日                    木
# 店舗名      DSG MEGA WORLD
# 取材名           chiiips取材
# 媒体名       ChiiiPS(チップス)
# 取材ランク                 ・
# Name: 9, dtype: object
# 10 都道府県               石川県
# イベント日       2023-03-16
# 曜日                   木
# 店舗名          APOLLO長田店
# 取材名          chiiips取材
# 媒体名      ChiiiPS(チップス)
# 取材ランク                ・
# Name: 10, dtype: object

# %%
# Sessionの作成
session = scoped_session(sessionmaker(autocommit = False,autoflush = False,bind = engine))
# modelで使用する
Base = declarative_base()
Base.query = session.query_property()
# Out:
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_36832\545109162.py:4: MovedIn20Warning: The ``declarative_base()`` function is now available as sqlalchemy.orm.declarative_base(). (deprecated since: 2.0) (Background on SQLAlchemy 2.0 at: https://sqlalche.me/e/b8d9)
#   Base = declarative_base()

# %%
from sqlalchemy import create_engine, text
query = "select * from schedule where 店舗名 = 'クァトロブーム金沢'"
df = pd.read_sql_query(sql=text(query), con=engine.connect())
df
# Out:
#    id 都道府県       イベント日 曜日        店舗名        取材名            媒体名 取材ランク  \
# 0   1  石川県  2023-03-14  火  クァトロブーム金沢  chiiips取材  ChiiiPS(チップス)     ・
# 1   2  石川県  2023-03-14  火  クァトロブーム金沢  chiiips取材  ChiiiPS(チップス)     ・
#
#                  取得時間
# 0 2023-03-14 23:14:34
# 1 2023-03-14 23:15:03
