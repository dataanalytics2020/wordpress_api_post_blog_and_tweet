# %%
# -*- coding: utf-8 -*-
import requests
import json
import base64
from wordpress_xmlrpc.methods import media
from oauth2client.service_account import ServiceAccountCredentials
import gspread
from wordpress_xmlrpc.methods.posts import GetPosts, NewPost
from wordpress_xmlrpc.methods.users import GetUserInfo
from wordpress_xmlrpc.methods import media, posts
from wordpress_xmlrpc.compat import xmlrpc_client
from wordpress_xmlrpc import Client, WordPressPost
from PIL import Image, ImageDraw, ImageFont
from dateutil.relativedelta import relativedelta
import matplotlib.pyplot as plt
import os
from selenium import webdriver
import time
import pandas as pd
from selenium.webdriver.common.alert import Alert
from selenium.webdriver.support.ui import Select
import urllib
from bs4 import BeautifulSoup
import re
import csv
import codecs
import requests
import urllib.request as req
import glob
import json
from matplotlib.ticker import MaxNLocator
import matplotlib.ticker as ticker
from matplotlib import rcParams
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.options import Options
from datetime import timedelta
import datetime
import os
from dotenv import load_dotenv
from selenium.webdriver.common.by import By
from wordpress_xmlrpc import Client, WordPressPost, methods
from src.utils import *
from urllib.parse import urljoin
import mysql
import mysql.connector
import urllib.request


print('ライブラリの読み込み完了')
try:
    from src.utils import *
except:
    from utils import *

# .envファイルの内容を読み込見込む
load_dotenv()
# Out:
# 読み込み完了
# ライブラリの読み込み完了
# True

# %%
class Blog():

    def __init__(self):
        WORDPRESS_ID = os.environ['WORDPRESS_ID']
        WORDPRESS_PW = os.environ['WORDPRESS_PW']
        WORDPRESS_URL = os.environ['WORDPRESS_URL']
        
        self.wp = Client(WORDPRESS_URL, WORDPRESS_ID, WORDPRESS_PW)
        
    def check_url(self,url,pledge_name):
        flag = True
        try:
            f = urllib.request.urlopen(url)
            #print('OK:', url)
            f.close()
        except urllib.request.HTTPError:
            print('Not found:', pledge_name,url)
            flag = False

        return flag

    def add_target_date (self, target_day_number:int):
        week_list = [ '(日)','(月)', '(火)', '(水)', '(木)', '(金)', '(土)','(日)']
        target_date:datetime = datetime.date.today() + datetime.timedelta(days=target_day_number)
        #datetime(2023,3,3)
        self.target_date:datetime = datetime.date.today() + datetime.timedelta(days=target_day_number)
        #3月3日(火)
        self.target_date_string_jp:str = target_date.strftime('%m').lstrip('0') + '月' + target_date.strftime('%d').lstrip('0') + '日'  +week_list[target_date.isoweekday()]
        #2023-03-03
        self.target_date_string_sql:str = target_date.strftime('%Y-%m-%d')
        print(f'インスタンに日付:{self.target_date_string_jp}など三つの変数が追加されました')
    
    def upload_image(self,in_image_file_name, out_image_file_name):
        if os.path.exists(in_image_file_name):
            with open(in_image_file_name, 'rb') as f:
                binary = f.read()

            data = {
                "name": out_image_file_name,
                "type": 'image/png',
                "overwrite": True,
                "bits": binary
            }

            media_id = self.wp.call(media.UploadFile(data))['id']
            print(in_image_file_name.split('/')
                [-1], 'Upload Success : id=%s' % media_id)
            return media_id
        else:
            print(in_image_file_name.split('/')[-1], 'NO IMAGE!!')

    def post_line(self,message):
        url = "https://notify-api.line.me/api/notify"
        token = os.environ['LINE_TOKEN']
        headers = {"Authorization" : "Bearer "+ token}
        payload = {"message" :  message}
        #imagesフォルダの中のgazo.jpg
        #print('image_path',image_path)
        #files = {"imageFile":open(image_path,'rb')}
        post = requests.post(url ,headers = headers ,params=payload) 


    def get_post_list(self) -> list[any]:
        '''投稿一覧を取得する関数
        一回で100記事まで取得できる'''
        post_list:list[WordPressPost] = self.wp.call(methods.posts.GetPosts({"number": 50, "offset":0}))
        self.post_list = post_list
        return self.post_list

    def generate_thumbnail(self) :
        image_path = r'image\image_source\千葉.jpg'  # mac
        image = Image.open(image_path)
        draw = ImageDraw.Draw(image)
        write_image_context = f'''{self.target_date_string_jp }\n{self.prefecture_name}\n取材予定まとめ'''
        font_path = r"font/LightNovelPOPv2.otf"
        font = ImageFont.truetype(font_path, size=240)
        draw.multiline_text((130, 20), write_image_context, fill=(255, 255, 255),align='center',font=font, spacing=50, stroke_width=5, stroke_fill=(55, 55, 55))
        thumbnail_image_path = fr'image\temp_image\thumbnail_{self.target_date}_{self.prefecture_name}.jpg'
        image.save(thumbnail_image_path)
        self.thumbnail_image_path = thumbnail_image_path


    def post_blog(self,main_text):
        title = f"【{self.prefecture_name}】{self.target_date_string_jp} パチンコスロットイベント取材まとめ"
        # Blog Content (html)
        body = main_text
        # publish or draft
        status = 'draft' # "publish"　or# 'draft'

        # Category keyword
        cat1 = '取材予定まとめ'
        cat2 = ''
        cat3 = ''

        # Tag keyword
        tag1 = f'{self.prefecture_name}'
        #tag2 = f'{self.target_date}'

        slug = f"pledge_report_{self.target_date}_{self.prefecture_name}"

        # Post
        post = WordPressPost()
        post.title = title
        post.content = body
        post.post_status = status
        post.terms_names = {
            "category": [cat1],
            "post_tag": [tag1],
        }
        post.slug = slug

        #サムネイル関連
        output_thumbnail_path = f'thumbnail_{self.target_date}_{self.prefecture_name}.jpg'
        media_id = self.upload_image(self.thumbnail_image_path, output_thumbnail_path)
        post.thumbnail = media_id

        #Post Time
        #post.date = datetime.datetime.now()

        self.wp.call(NewPost(post))
        print('記事書き込み完了')
        # except Exception as e:
    #     post_line(f'{tomorrow}分ブログ投稿失敗\n{e}')
    
    def wp_update_post(self,content_id:int,content_text:str) -> dict:
        
        # URL, User, Password設定
        WP_URL: str = os.getenv('WP_URL')
        WP_USER: str = os.getenv('WP_USER')
        WP_API_PASSWORD: str = os.getenv('REST_API_PW')
        API_URL = f"{WP_URL}/wp-json/wp/v2/"
        url = f'{WP_URL}/wp-json/wp/v2/posts/{content_id}'
        credentials = WP_USER + ':' + WP_API_PASSWORD
        token = base64.b64encode(credentials.encode())
        headers = {'Authorization': 'Basic ' + token.decode('utf-8')}

        post = {f'content': content_text,
                'status': 'publish'}
        res = requests.post(f"{WP_URL}/wp-json/wp/v2/posts/{content_id}", headers=headers, json=post)
        if res.ok:
            print("投稿の更新 成功 code:{res.status_code}")
            return json.loads(res.text)
        else:
            print(f"投稿の更新 失敗 code:{res.status_code} reason:{res.reason} msg:{res.text}")
            return {}

    def wp_tag_add(self,tagname:str) -> int:
        
        WP_URL: str = os.getenv('WP_URL')
        WP_USER: str = os.getenv('WP_USER')
        WP_API_PASSWORD: str = os.getenv('REST_API_PW')
        API_URL = f"{WP_URL}/wp-json/wp/v2/"
        TAG_URL = urljoin(WP_URL, '/wp-json/wp/v2/tags/')
        r = ""
        post = {
            'name': tagname,
        }
        res = requests.post(
            TAG_URL ,
            json=post,
            auth=(WP_USER, WP_API_PASSWORD),
            )
        data = json.loads(res.text)
        if 'code' in data:
            if data['code'] == "term_exists":
                r = data['data']['term_id']
                print(r)
        else:
            r = data['id']
            print(r)
        return r
    
    def create_main_text(self,save_main_image_path_list,merged_syuzai_pledge_df):
        main_text = f'''
[st-kaiwa1]【{self.prefecture_name}】{self.target_date_string_jp }　パチンコホールイベント取材まとめ記事です。

イベントの公約に基づき、高設定が投入される可能性が高いと予想されるホールを中心に公約内容も一緒にわかりやすく明日のイベントのある店舗を紹介しています。

毎日更新されますので是非、ブックマークお願いします。[/st-kaiwa1]
<h3>更新時間:{datetime.datetime.now().strftime("%m月%d日%H時%m分")}</h3>
<h2>{self.prefecture_name}  パチンコ・スロット イベント 取材まとめ・オススメ店舗順一覧画像</h2>
'''
        print(main_text)
        image_url_head_text:str = f'http://slotana777.com/wp-content/uploads/{datetime.datetime.now().strftime("%Y")}/{datetime.datetime.now().strftime("%m")}/'
        for input_image_path in save_main_image_path_list:
            output_path = input_image_path.replace('image\\temp_image\\','')
            output_path = output_path.split('.')[0] + f'_updatetime_' + datetime.datetime.now().strftime('%m-%d') +'.' +output_path.split('.')[1]
            print(output_path)
            self.upload_image(input_image_path, output_path)
            main_text  += f'''\n<a href="{image_url_head_text}{output_path}">\n<img src="{image_url_head_text}{output_path}" alt="{self.prefecture_name}_{self.target_date_string_sql}_パチンコ・パチスロ_イベント" class="alignnone size-full " /></a>'''

        html_table_df = merged_syuzai_pledge_df[['店舗名','取材名','媒体名','公約内容']]
        html_table_df['イベント日'] = self.target_date_string_jp
        html_table_df = html_table_df[['店舗名','取材名','媒体名','公約内容']]
        print(html_table_df.to_html(index=False))

        main_text += f'<h2>{self.prefecture_name} {self.target_date_string_jp} パチンコ・スロット イベント 取材まとめ・オススメ店舗順一覧</h2>'
        main_text += '\n' + html_table_df.to_html(index=False)
        self.main_text = main_text
        return self.main_text

    def generate_by_pledge_text(self,merged_syuzai_pledge_df,scraping):
        input_by_pledge_text = '\n'
        pledge_name_list:list[str] = list(merged_syuzai_pledge_df['媒体名'].unique())
        for pledge_name in ['フリー','その他','未調査']:
            try:
                pledge_name_list.remove(pledge_name)
                pledge_name_list.append(pledge_name)
            except:
                pass
        for pledge_name in pledge_name_list:
            extract_pledge_name_df = merged_syuzai_pledge_df[merged_syuzai_pledge_df['媒体名'] == pledge_name]
            encoced_plefge_name = urllib.parse.quote(pledge_name)
            header_url:str = f'http://slotana777.com/wp-content/uploads/2023/04/{encoced_plefge_name}.jpg'
            if self.check_url(header_url,pledge_name):
                input_by_pledge_text += f'<img src="http://slotana777.com/wp-content/uploads/2023/04/{pledge_name}.jpg" alt="{pledge_name}" width="1000" height="400" class="size-full " />\n'
            else:
                h2_banner_text:str =f'''<div class="box-alert box-alert-info">
        <i class="fas fa-exclamation-circle fa-4x"></i>
        <div class="alert-message">
            <div class="alert-title">{pledge_name}</div>
            <p>{scraping.target_date_string_jp}  {scraping.prefecture_name}</p>
        </div></div>'''
                #print(h2_banner_text)
                input_by_pledge_text += '\n' + h2_banner_text
            #display(extract_pledge_name_df )
            #break
            rank_replace_dict:dict[str] = {'S':'<h4 class="rankh4 rankno-1">','A':'<h4 class="rankh4 rankno-2">','B':'<h4 class="rankh4 rankno-3">','C':'<h4 class="rankh4 rankno-4">','・':'<h4 class="rankh4 rankno-4">'}
            for rank in ['S','A','B','C','・']:
                extract_syuzai_name_df  = extract_pledge_name_df[extract_pledge_name_df['取材ランク'] == rank]
                #display(extract_syuzai_name_df)
                for syuzai_name in extract_syuzai_name_df['取材名'].unique():
                    input_by_pledge_text += '<div class="redbox"><h5><span class="oomozi"><strong>' + syuzai_name + '</strong></span></h5>\n'
                    extract_parlar_name_df  = extract_pledge_name_df[extract_pledge_name_df['取材名'] == syuzai_name]
                    pre_pledge_name = ''
                    for i,row in extract_parlar_name_df.iterrows():
                        if pre_pledge_name != row['取材名']:
                            input_by_pledge_text += f'\n<span class="hatenamark2 on-color">公約:{row["公約内容"]}</span>'
                            input_by_pledge_text += f'\n{rank_replace_dict[rank]} {row["店舗名"]}</strong></span></h4>'
                        else:
                            input_by_pledge_text += f'\n{rank_replace_dict[rank]} {row["店舗名"]}</strong></span></h4>'
                        pre_pledge_name = row['取材名']
                    input_by_pledge_text +='</div>'  
            # if len(extract_pledge_name_df ) != 0:
            #     # print('\n■',baitai,sep='')
            #     winput_by_pledge_text += '<h3>' + string_date_only + ' ' + todoufuken_kanji + ' スロット ' + baitai + '</h3>' + f'\n<img src="http://slotana777.com/wp-content/uploads/2021/04/{error_baitai}.jpg" alt="{error_baitai} タイトル画像" width="1000" height="400" class="alignnone size-full " />\n'
            # else:
            #     pass
            #break
        print(input_by_pledge_text)
        self.input_by_pledge_text = input_by_pledge_text
        return self.input_by_pledge_text

# %%
merged_syuzai_pledge_df[merged_syuzai_pledge_df['媒体名'] == 'スロパチステーション']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 merged_syuzai_pledge_df[merged_syuzai_pledge_df['媒体名'] == 'スロパチステーション']
#
# NameError: name 'merged_syuzai_pledge_df' is not defined

# %%
class PledgeScraping():

    def add_target_date(self, target_day_number:int):
        week_list = [ '(日)','(月)', '(火)', '(水)', '(木)', '(金)', '(土)','(日)']
        target_date:datetime = datetime.date.today() + datetime.timedelta(days=target_day_number)
        #datetime(2023,3,3)
        self.target_date:datetime = datetime.date.today() + datetime.timedelta(days=target_day_number)
        #3月3日(火)
        self.target_date_string_jp:str = target_date.strftime('%m').lstrip('0') + '月' + target_date.strftime('%d').lstrip('0') + '日'  +week_list[target_date.isoweekday()]
        #2023-03-03
        self.target_date_string_sql:str = target_date.strftime('%Y-%m-%d')
        print(f'インスタンに日付:{self.target_date_string_jp}など三つの変数が追加されました')

    def login_scraping_site(self,area_name):
        global browser
        options = Options()
        options.add_argument('--headless')
        options.add_argument("--no-sandbox")
        browser = webdriver.Chrome(ChromeDriverManager().install(),options=options)#ChromeDriverManager().install()
        browser.implicitly_wait(10)
        url_login = f"https://{os.getenv('SCRAPING_SYUZAI_DOMAIN')}/login_form_mail"
        #admageを開く
        browser.get(url_login)
        browser.implicitly_wait(10)
        # id
        element = browser.find_element(By.NAME,"id")
        element.click()
        element.clear()
        browser.implicitly_wait(10)
        element.send_keys(os.getenv('REPORT_SITE_ID'))
        # pw
        element = browser.find_element(By.NAME,"pass")
        element.click()
        element.clear()
        browser.implicitly_wait(10)
        element.send_keys(os.getenv('REPORT_SITE_PW'))
        browser.implicitly_wait(10)
        element = browser.find_element(By.CLASS_NAME,"box_hole_view_report_input")
        element.click()
        browser.implicitly_wait(10)
        url = f"https://{os.getenv('SCRAPING_SYUZAI_DOMAIN')}/select_area"
        browser.get(url)
        browser.implicitly_wait(10)
        url = f"https://{os.getenv('SCRAPING_SYUZAI_DOMAIN')}/?area={area_name}"
        browser.get(url)
        browser.implicitly_wait(10)
        self.browser =browser
        return self.browser

#エリアの都道府県の名前と対応番号を取得

    def get_prefecture_name_and_number_dict(self):
        prefectures_box_elements = browser.find_element(By.CLASS_NAME,"one_sp_block")
        prefectures_elements:list = prefectures_box_elements.find_elements(By.CLASS_NAME,"mgn_serch_list_bottom")
        prefecture_name_and_number_dict:dict[str:str] = {}

        for element in prefectures_elements:
            prefecture_name:str = element.find_element(By.CLASS_NAME,"side_bar_L_O").text
            #print(prefecture_name)
            link_url:str = element.find_element(By.TAG_NAME,'a').get_attribute('href')
            prefecture_number:int = link_url.split('ken=')[-1]
            #print(prefecture_number)
            prefecture_name_and_number_dict[prefecture_name] = prefecture_number

        self.prefecture_name_and_number_dict = prefecture_name_and_number_dict
        return self.prefecture_name_and_number_dict
    
    def read_target_date_pledge_df(self,prefecture_name:str):
        browser = self.browser
        self.prefecture_name = prefecture_name
        furture_syuzai_list_df = pd.DataFrame(index=[], columns=['都道府県','イベント日','店舗名','取材名','取材ランク'])
        prefecture_number:int = int(self.prefecture_name_and_number_dict[prefecture_name])
        url = f"https://{os.getenv('SCRAPING_SYUZAI_DOMAIN')}/osusume_list?ken={self.prefecture_name}&ymd={self.target_date_string_sql}"
        browser.get(url)
        browser.implicitly_wait(10)
        kiji_element_box = browser.find_element(By.CLASS_NAME,"osusume_list_container")
        kiji_elements_list:list = kiji_element_box.find_elements(By.CLASS_NAME,"osbox")

        for i,syuzai_record_element in enumerate(kiji_elements_list):
            if 'プレミアム会員登録' == browser.find_element(By.CLASS_NAME,"menu_child").text:
                browser = self.login_scraping_site('chubu')
                url = f"https://{os.getenv('SCRAPING_SYUZAI_DOMAIN')}/osusume_list?ken={self.target_date_string_sql}&ymd={self.target_date_string_sql}"
                browser.get(url)
                browser.implicitly_wait(10)
            else:
                pass
            #print(syuzai_record_element.text)
            syuzai_record_element_list = syuzai_record_element.find_elements(By.CLASS_NAME,"list_event_name")
            browser.implicitly_wait(1)
            #print(syuzai_record_element_list)
            if len(syuzai_record_element_list) == 0:
                continue
            tenpo_name = syuzai_record_element.find_element(By.CLASS_NAME,"oslh2").text
            for syuzai_name_element in syuzai_record_element_list:
                #print(syuzai_name_element.text)
                syuzai_rank = syuzai_name_element.find_element(By.CLASS_NAME,"list_event_name_rank").text
                schedule_name = syuzai_name_element.find_element(By.CLASS_NAME,"list_event_name_li").text
                #print(tenpo_name,syuzai_rank,schedule_name)
                record = pd.Series([prefecture_name,self.target_date_string_sql, tenpo_name,schedule_name,syuzai_rank], index=furture_syuzai_list_df.columns)
                furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)

        self.furture_syuzai_list_df = furture_syuzai_list_df
        return self.furture_syuzai_list_df

    def read_convert_parlar_name_df(self):
        cnx = mysql.connector.connect(
                        user = os.getenv('DB_USER_NAME'),
                        password=os.getenv('DB_PASSWORD'), 
                        host=os.getenv('DB_HOST'), 
                        port='3306',
                        database=os.getenv('DB_NAME'))
        cursor = cnx.cursor()
        sql = f"""SELECT * FROM pledge"""
        print(sql)
        cursor.execute(sql)
        #cols = [col[0] for col in cursorsor.description]
        convert_parlar_name_df = pd.DataFrame(cursor.fetchall(),columns = ['id','取材名','媒体名','公約内容','取得時間'])
        self.convert_parlar_name_df = convert_parlar_name_df
        return self.convert_parlar_name_df
    
    def generate_merged_syuzai_pledge_df(self):
        merged_syuzai_pledge_df = pd.merge(self.furture_syuzai_list_df,self.convert_parlar_name_df,how='left',on='取材名')
        merged_syuzai_pledge_df = merged_syuzai_pledge_df[~merged_syuzai_pledge_df['取材名'].str.contains('ナビ子')]
        merged_syuzai_pledge_df = merged_syuzai_pledge_df.fillna('未調査')
        merged_syuzai_pledge_df = merged_syuzai_pledge_df.replace({'': '未調査'})
        self.merged_syuzai_pledge_df = merged_syuzai_pledge_df
        return self.merged_syuzai_pledge_df
    
    def recommend_image(self,write_image_context, length,read_image_path,save_image_jpg):
        image = Image.open(read_image_path)
        draw = ImageDraw.Draw(image)
        # フォントを指定
        font_path = r"font\LightNovelPOPv2.otf"
        font = ImageFont.truetype(font_path, size=40)

        # 文字を描く
        # 最初の(0,0)は文字の描画を開f始する座標位置です　もちろん、(10,10)などでもOK
        # fillはRGBで文字の色を決めています
        draw.multiline_text((55, 40), write_image_context, fill=(255, 255, 255), font=font, spacing=10, stroke_width=5, stroke_fill=(55, 55, 55))

        # 画像を保存する
        image.save(save_image_jpg)
        print('length', length)
        length_croped = 110 + length * 66  # 500
        im = Image.open(save_image_jpg)
        im_crop = im.crop((0, 0, 1000, length_croped))
        im_crop.save(save_image_jpg, quality=100)

    def create_pledge_main_images(self):
        read_image_path:str = r"image\image_source\eva_board.jpg"
        create_image_number:int = 0
        parlar_name_count:int = 0
        schedule_text:str = ''
        last_time_parlar_name:str = ''
        save_main_image_path_list:list[str] = []
        for i,row in self.merged_syuzai_pledge_df.iterrows():
            #print(row)
            print(row['店舗名'],last_time_parlar_name )
            if last_time_parlar_name != row['店舗名']:
                schedule_text += '\n◆' +  row['店舗名'] + '\n'
                parlar_name_count += 1
                #print(parlar_name_count)
            else:
                pass


            if row['取材名'].startswith(tuple(['旧イベ'])):
                schedule_text += '　☆' + row['取材名']  + '\n'
                last_time_parlar_name = row['店舗名']
                continue
            else:
                schedule_text += '　☆' + row['取材名'] + ' 【' + row['媒体名'] + '】' + '\n'


            if (str(row['公約内容']) == 'nan') or (row['公約内容'] == None) or (row['公約内容'] == ''):
                schedule_text += '       ┗' + '未調査' + '\n'
            else:
                schedule_text += '       ┗' + row['公約内容'] + '\n'

            last_time_parlar_name = row['店舗名']
            #print(parlar_name_count)
            if (parlar_name_count > 9 ) or self.merged_syuzai_pledge_df.index[-1] == i :
                #print('処理開始')
                create_image_number  += 1
                title = f'{self.prefecture_name} {self.target_date_string_jp} スロットイベントまとめ{create_image_number}\n'
                input_image_text : str = title + schedule_text
                text__row_length = input_image_text.count('\n')
                #print('length', text__row_length )
                print(input_image_text)
                save_image_jpg = fr"image\temp_image\eva_board_{self.prefecture_name}_{self.target_date_string_sql}_{create_image_number}.jpg"
                self.recommend_image(input_image_text, text__row_length ,read_image_path,save_image_jpg)
                save_main_image_path_list.append(save_image_jpg)
                schedule_text = ''
                last_time_parlar_name = ''
                parlar_name_count = 0
        self.save_main_image_path_list = save_main_image_path_list
        return self.save_main_image_path_list

# %%
blog = Blog()
post_list = blog.get_post_list()
post_title_contentid_dict:dict[str:int] = {}
for post in post_list:
    post_title_contentid_dict[post.title] = int(post.id)

scraping = PledgeScraping()

for target_day_number in range(5,6):
    scraping.add_target_date(target_day_number)
    browser = scraping.login_scraping_site('chubu')
    prefecture_name_and_number_dict = scraping.get_prefecture_name_and_number_dict()
    for prefecture_name in prefecture_name_and_number_dict:
        blog = Blog()
        print(prefecture_name,target_day_number)
        blog.add_target_date (target_day_number)
        blog.prefecture_name = prefecture_name
        print(prefecture_name)
        scraping_target_date_pledge_df = scraping.read_target_date_pledge_df(prefecture_name)
        read_convert_parlar_name_df = scraping.read_convert_parlar_name_df()
        merged_syuzai_pledge_df = scraping.generate_merged_syuzai_pledge_df()
        save_main_image_path_list = scraping.create_pledge_main_images()
        title = f"【{blog.prefecture_name}】{blog.target_date_string_jp } パチンコスロットイベント取材まとめ"
        if title in post_title_contentid_dict:
            update_content_id:int = int(post_title_contentid_dict[title])
            print('既存の記事を更新します',update_content_id)
            files:list[Client] = blog.wp.call(methods.media.GetMediaLibrary({"parent_id": update_content_id}))
            for file in files:
                print('画像削除',file.id, file.title)
                ret = blog.wp.call(methods.posts.DeletePost(file.id))
                print(ret)
                #break

            main_text:str = blog.create_main_text(save_main_image_path_list,merged_syuzai_pledge_df)
            generate_by_pledge_text = blog.generate_by_pledge_text(merged_syuzai_pledge_df,scraping)
            main_text  += generate_by_pledge_text
            blog.wp_update_post(update_content_id, main_text )
            blog.post_line(f'既存記事を更新しました。\n{prefecture_name}_{blog.target_date_string_jp}')
        else:
            print('新しい記事を作成します')
            print(title)
            blog.generate_thumbnail()
            main_text:str = blog.create_main_text(save_main_image_path_list,merged_syuzai_pledge_df)
            generate_by_pledge_text = blog.generate_by_pledge_text(merged_syuzai_pledge_df,scraping)
            main_text  += generate_by_pledge_text
            blog.post_blog(main_text)
            blog.post_line(f'新しい記事を作成しました。\n{prefecture_name}_{blog.target_date_string_jp}')
        break
    break
# Out:
# インスタンに日付:4月9日(日)など三つの変数が追加されました
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:19: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   browser = webdriver.Chrome(ChromeDriverManager().install(),options=options)#ChromeDriverManager().install()
# 愛知県 5
# インスタンに日付:4月9日(日)など三つの変数が追加されました
# 愛知県
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\174999915.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   furture_syuzai_list_df = furture_syuzai_list_df.append(record, ignore_index=True)
# SELECT * FROM pledge
# メガコンコルド800春日井店+
# ラッキープラザ名古屋西インター七宝店 メガコンコルド800春日井店+
# 京楽会館 豊明店 ラッキープラザ名古屋西インター七宝店
# 京楽会館 豊明店 京楽会館 豊明店
# メガコンコルド1111BLAZE店 京楽会館 豊明店
# メガガイア一宮 メガコンコルド1111BLAZE店
# メガガイア一宮 メガガイア一宮
# ミカド一宮インター店 メガガイア一宮
# マルシン東刈谷店 ミカド一宮インター店
# マルシン東刈谷店 マルシン東刈谷店
# イクサム岡崎西店 マルシン東刈谷店
# イクサム岡崎西店 イクサム岡崎西店
# イクサム甚目寺店 イクサム岡崎西店
# イクサム甚目寺店 イクサム甚目寺店
# プレイランド平和大治店 イクサム甚目寺店
# 愛知県 4月9日(日) スロットイベントまとめ1
#
# ◆メガコンコルド800春日井店+
# 　☆サプライズスロッター 【パチンコ店長のホール攻略】
#        ┗未調査
#
# ◆ラッキープラザ名古屋西インター七宝店
# 　☆旧イベ(9のつく日)
#
# ◆京楽会館 豊明店
# 　☆プレミアムジャッジメントP 【アツ姫】
#        ┗未調査
# 　☆プレミアムジャッジメントS 【アツ姫】
#        ┗未調査
#
# ◆メガコンコルド1111BLAZE店
# 　☆潜入取材ギガテン 【スロパチステーション】
#        ┗未調査
#
# ◆メガガイア一宮
# 　☆かたまる×スロパチステーション潜入取材 結 【スロパチステーション】
#        ┗未調査
# 　☆旧イベ(9のつく日)
#
# ◆ミカド一宮インター店
# 　☆マキシマムスロッター 【パチンコ店長のホール攻略】
#        ┗未調査
#
# ◆マルシン東刈谷店
# 　☆超HiTension取材 【でちゃう！】
#        ┗未調査
# 　☆でちゃう編集部来店(かおりん) 【でちゃう！】
#        ┗未調査
#
# ◆イクサム岡崎西店
# 　☆スロッター×スロッター 【パチンコ店長のホール攻略】
#        ┗4つの公約が存在。要HPチェック
# 　☆旧イベ(9のつく日)
#
# ◆イクサム甚目寺店
# 　☆スロッター×スロッター 【パチンコ店長のホール攻略】
#        ┗4つの公約が存在。要HPチェック
# 　☆旧イベ(9のつく日)
#
# ◆プレイランド平和大治店
# 　☆スロッター×スロッター 【パチンコ店長のホール攻略】
#        ┗4つの公約が存在。要HPチェック
#
# length 47
# メガコンコルド1220みなと23号通り店
# メガコンコルド1220みなと23号通り店 メガコンコルド1220みなと23号通り店
# コンコルド880愛西日比野駅前店 メガコンコルド1220みなと23号通り店
# コンコルド800 一宮尾西インター店 コンコルド880愛西日比野駅前店
# キング666一宮店 コンコルド800 一宮尾西インター店
# キング観光サウザンド名古屋駅柳橋店 キング666一宮店
# キング観光サウザンド名古屋駅柳橋店 キング観光サウザンド名古屋駅柳橋店
# GOGO千代田 キング観光サウザンド名古屋駅柳橋店
# KEIZ大高店 GOGO千代田
# KEIZ大高店 KEIZ大高店
# メガコンコルド555西尾店 KEIZ大高店
# メガコンコルド555西尾店 メガコンコルド555西尾店
# メガコンコルド555西尾店 メガコンコルド555西尾店
# ミカドWORLD店 メガコンコルド555西尾店
# ミカドWORLD店 ミカドWORLD店
# インディ刈谷店 ミカドWORLD店
# 愛知県 4月9日(日) スロットイベントまとめ2
#
# ◆メガコンコルド1220みなと23号通り店
# 　☆プレミアムジャッジメントP 【アツ姫】
#        ┗未調査
# 　☆スマートオフミー(初開催) 【オフミー】
#        ┗未調査
#
# ◆コンコルド880愛西日比野駅前店
# 　☆サプライズスロッター 【パチンコ店長のホール攻略】
#        ┗未調査
#
# ◆コンコルド800 一宮尾西インター店
# 　☆スロッター×スロッター 【パチンコ店長のホール攻略】
#        ┗4つの公約が存在。要HPチェック
#
# ◆キング666一宮店
# 　☆サプライズスロッター 【パチンコ店長のホール攻略】
#        ┗未調査
#
# ◆キング観光サウザンド名古屋駅柳橋店
# 　☆オフミー取材 【オフミー】
#        ┗全台形が数カ所入りやすい
# 　☆パチミー取材 【オフミー】
#        ┗未調査
#
# ◆GOGO千代田
# 　☆魔法ちゃん来店 【その他取材・企画】
#        ┗未調査
#
# ◆KEIZ大高店
# 　☆ガチスロ 【リアルガチホール】
#        ┗未調査
# 　☆ガチパチ 【未調査】
#        ┗未調査
#
# ◆メガコンコルド555西尾店
# 　☆パチンカー×パチンカー 【パチンコ店長のホール攻略】
#        ┗パチンコ2機種以上で分岐営業
# 　　　対象機種はHP要確認
# 　☆スロッター×スロッター6.5 【パチンコ店長のホール攻略】
#        ┗未調査
# 　☆カリスマ取材 【でちゃう！】
#        ┗未調査
#
# ◆ミカドWORLD店
# 　☆マキシマムスロッター 【パチンコ店長のホール攻略】
#        ┗未調査
# 　☆IMCいむちゃんねる 収録予定 【IMCいむちゃんねる】
#        ┗未調査
#
# ◆インディ刈谷店
# 　☆ゲンキー実践取材 【スロスタ】
#        ┗未調査
#
# length 54
# インディ刈谷店
# ラッキープラザ1111弥富店 インディ刈谷店
# ラッキープラザ1111弥富店 ラッキープラザ1111弥富店
# ミカド稲沢店 ラッキープラザ1111弥富店
# ラッキープラザ大府店 ミカド稲沢店
# ラッキープラザ大府店 ラッキープラザ大府店
# MEGAコンコルド1280稲沢店 ラッキープラザ大府店
# PAO共和店 MEGAコンコルド1280稲沢店
# メガスロットコンコルド345吉浜店 PAO共和店
# メガスロットコンコルド345吉浜店 メガスロットコンコルド345吉浜店
# KYORAKU 西店 メガスロットコンコルド345吉浜店
# ミカド一宮本店 KYORAKU 西店
# G&L一宮店 ミカド一宮本店
# 愛知県 4月9日(日) スロットイベントまとめ3
#
# ◆インディ刈谷店
# 　☆シューティングスター 【未調査】
#        ┗未調査
#
# ◆ラッキープラザ1111弥富店
# 　☆求道者取材 【でちゃう！】
#        ┗未調査
# 　☆旧イベ(9のつく日)
#
# ◆ミカド稲沢店
# 　☆マキシマムスロッター 【パチンコ店長のホール攻略】
#        ┗未調査
#
# ◆ラッキープラザ大府店
# 　☆ナイン×スロッター 【パチンコ店長のホール攻略】
#        ┗未調査
# 　☆旧イベ(9のつく日)
#
# ◆MEGAコンコルド1280稲沢店
# 　☆スロッター×パチンカー 【パチンコ店長のホール攻略】
#        ┗スロッター×2とパチンカー×2の同時開催
#
# ◆PAO共和店
# 　☆スロッター×パチンカー 【パチンコ店長のホール攻略】
#        ┗スロッター×2とパチンカー×2の同時開催
#
# ◆メガスロットコンコルド345吉浜店
# 　☆スロッター×スロッターSMART 【パチンコ店長のホール攻略】
#        ┗未調査
# 　☆スロッター×スロッター6.5 【パチンコ店長のホール攻略】
#        ┗未調査
#
# ◆KYORAKU 西店
# 　☆旧イベ(9のつく日)
#
# ◆ミカド一宮本店
# 　☆マキシマムスロッター 【パチンコ店長のホール攻略】
#        ┗未調査
#
# ◆G&L一宮店
# 　☆パチンカー×パチンカー 【パチンコ店長のホール攻略】
#        ┗パチンコ2機種以上で分岐営業
# 　　　対象機種はHP要確認
#
# length 45
# G&L一宮店
# ラッキープラザ津島店 G&L一宮店
# ラッキープラザ津島店 ラッキープラザ津島店
# ラッキープラザ津島店 ラッキープラザ津島店
# ZENT稲沢店 ラッキープラザ津島店
# キャッスル大金店 ZENT稲沢店
# プレイランド第一平和 キャッスル大金店
# キャッスル岩倉店 プレイランド第一平和
# 愛知県 4月9日(日) スロットイベントまとめ4
#
# ◆G&L一宮店
# 　☆ズバパチミレニアム 【あかだ主任のガチンコ…】
#        ┗未調査
#
# ◆ラッキープラザ津島店
# 　☆必勝本ライター来店情報 【パチスロ必勝本】
#        ┗来店実践
# 　☆求道者取材 【でちゃう！】
#        ┗未調査
# 　☆旧イベ(9のつく日)
#
# ◆ZENT稲沢店
# 　☆スロッター×スロッター 【パチンコ店長のホール攻略】
#        ┗4つの公約が存在。要HPチェック
#
# ◆キャッスル大金店
# 　☆マキシマムスロッター 【パチンコ店長のホール攻略】
#        ┗未調査
#
# ◆プレイランド第一平和
# 　☆パチンカー×パチンカー 【パチンコ店長のホール攻略】
#        ┗パチンコ2機種以上で分岐営業
# 　　　対象機種はHP要確認
#
# ◆キャッスル岩倉店
# 　☆マキシマムスロッター 【パチンコ店長のホール攻略】
#        ┗未調査
#
# length 29
# 新しい記事を作成します
# 【愛知県】4月9日(日) パチンコスロットイベント取材まとめ
#
# [st-kaiwa1]【愛知県】4月9日(日)　パチンコホールイベント取材まとめ記事です。
#
# イベントの公約に基づき、高設定が投入される可能性が高いと予想されるホールを中心に公約内容も一緒にわかりやすく明日のイベントのある店舗を紹介しています。
#
# 毎日更新されますので是非、ブックマークお願いします。[/st-kaiwa1]
# <h3>更新時間:04月04日02時04分</h3>
# <h2>愛知県  パチンコ・スロット イベント 取材まとめ・オススメ店舗順一覧画像</h2>
#
# eva_board_愛知県_2023-04-09_1_updatetime_04-04.jpg
# image\temp_image\eva_board_愛知県_2023-04-09_1.jpg Upload Success : id=39175
# eva_board_愛知県_2023-04-09_2_updatetime_04-04.jpg
# image\temp_image\eva_board_愛知県_2023-04-09_2.jpg Upload Success : id=39176
# eva_board_愛知県_2023-04-09_3_updatetime_04-04.jpg
# image\temp_image\eva_board_愛知県_2023-04-09_3.jpg Upload Success : id=39177
# eva_board_愛知県_2023-04-09_4_updatetime_04-04.jpg
# image\temp_image\eva_board_愛知県_2023-04-09_4.jpg Upload Success : id=39178
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>店舗名</th>
#       <th>取材名</th>
#       <th>媒体名</th>
#       <th>公約内容</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>メガコンコルド800春日井店+</td>
#       <td>サプライズスロッター</td>
#       <td>パチンコ店長のホール攻略</td>
#       <td>未調査</td>
#     </tr>
#     <tr>
#       <td>ラッキープラザ名古屋西インター七宝店</td>
#       <td>旧イベ(9のつく日)</td>
#       <td>旧イベ</td>
#       <td>未調査</td>
#     </tr>
#     <tr>
#       <td>京楽会館 豊明店</td>
#       <td>プレミアムジャッジメントP</td>
#       <td>アツ姫</td>
#       <td>未調査</td>
#     </tr>
#     <tr>
#       <td>京楽会館 豊明店</td>
#       <td>プレミアムジャッジメントS</td>
#       <td>アツ姫</td>
#       <td>未調査</td>
#     </tr>
#     <tr>
#       <td>メガコンコルド1111BLAZE店</td>
#       <td>潜入取材ギガテン</td>
#       <td>スロパチステーション</td>
#       <td>未調査</td>
#     </tr>
#     <tr>
#       <td>メガガイア一宮</td>
#       <td>かたまる×スロパチステーション潜入取材 結</td>
#       <td>スロパチステーション</td>
#       <td>未調査</td>
#     </tr>
#     <tr>
#       <td>メガガイア一宮</td>
#       <td>旧イベ(9のつく日)</td>
#       <td>旧イベ</td>
#       <td>未調査</td>
#     </tr>
#     <tr>
#       <td>ミカド一宮インター店</td>
#       <td>マキシマムスロッター</td>
#       <td>パチンコ店長のホール攻略</td>
#       <td>未調査</td>
#     </tr>
#     <tr>
#       <td>マルシン東刈谷店</td>
#       <td>超HiTension取材</td>
#       <td>でちゃう！</td>
#       <td>未調査</td>
#     </tr>
#     <tr>
#       <td>マルシン東刈谷店</td>
#       <td>でちゃう編集部来店(かおりん)</td>
#       <td>でちゃう！</td>
#       <td>未調査</td>
#     </tr>
#     <tr>
#       <td>イクサム岡崎西店</td>
#       <td>スロッター×スロッター</td>
#       <td>パチンコ店長のホール攻略</td>
#       <td>4つの公約が存在。要HPチェック</td>
#     </tr>
#     <tr>
#       <td>イクサム岡崎西店</td>
#       <td>旧イベ(9のつく日)</td>
#       <td>旧イベ</td>
#       <td>未調査</td>
#     </tr>
#     <tr>
#       <td>イクサム甚目寺店</td>
#       <td>スロッター×スロッター</td>
#       <td>パチンコ店長のホール攻略</td>
#       <td>4つの公約が存在。要HPチェック</td>
#     </tr>
#     <tr>
#       <td>イクサム甚目寺店</td>
#       <td>旧イベ(9のつく日)</td>
#       <td>旧イベ</td>
#       <td>未調査</td>
#     </tr>
#     <tr>
#       <td>プレイランド平和大治店</td>
#       <td>スロッター×スロッター</td>
#       <td>パチンコ店長のホール攻略</td>
#       <td>4つの公約が存在。要HPチェック</td>
#     </tr>
#     <tr>
#       <td>メガコンコルド1220みなと23号通り店</td>
#       <td>プレミアムジャッジメントP</td>
#       <td>アツ姫</td>
#       <td>未調査</td>
#     </tr>
#     <tr>
#       <td>メガコンコルド1220みなと23号通り店</td>
#       <td>スマートオフミー(初開催)</td>
#       <td>オフミー</td>
#       <td>未調査</td>
#     </tr>
#     <tr>
#       <td>コンコルド880愛西日比野駅前店</td>
#       <td>サプライズスロッター</td>
#       <td>パチンコ店長のホール攻略</td>
#       <td>未調査</td>
#     </tr>
#     <tr>
#       <td>コンコルド800 一宮尾西インター店</td>
#       <td>スロッター×スロッター</td>
#       <td>パチンコ店長のホール攻略</td>
#       <td>4つの公約が存在。要HPチェック</td>
#     </tr>
#     <tr>
#       <td>キング666一宮店</td>
#       <td>サプライズスロッター</td>
#       <td>パチンコ店長のホール攻略</td>
#       <td>未調査</td>
#     </tr>
#     <tr>
#       <td>キング観光サウザンド名古屋駅柳橋店</td>
#       <td>オフミー取材</td>
#       <td>オフミー</td>
#       <td>全台形が数カ所入りやすい</td>
#     </tr>
#     <tr>
#       <td>キング観光サウザンド名古屋駅柳橋店</td>
#       <td>パチミー取材</td>
#       <td>オフミー</td>
#       <td>未調査</td>
#     </tr>
#     <tr>
#       <td>GOGO千代田</td>
#       <td>魔法ちゃん来店</td>
#       <td>その他取材・企画</td>
#       <td>未調査</td>
#     </tr>
#     <tr>
#       <td>KEIZ大高店</td>
#       <td>ガチスロ</td>
#       <td>リアルガチホール</td>
#       <td>未調査</td>
#     </tr>
#     <tr>
#       <td>KEIZ大高店</td>
#       <td>ガチパチ</td>
#       <td>未調査</td>
#       <td>未調査</td>
#     </tr>
#     <tr>
#       <td>メガコンコルド555西尾店</td>
#       <td>パチンカー×パチンカー</td>
#       <td>パチンコ店長のホール攻略</td>
#       <td>パチンコ2機種以上で分岐営業\r\n　　　対象機種はHP要確認</td>
#     </tr>
#     <tr>
#       <td>メガコンコルド555西尾店</td>
#       <td>スロッター×スロッター6.5</td>
#       <td>パチンコ店長のホール攻略</td>
#       <td>未調査</td>
#     </tr>
#     <tr>
#       <td>メガコンコルド555西尾店</td>
#       <td>カリスマ取材</td>
#       <td>でちゃう！</td>
#       <td>未調査</td>
#     </tr>
#     <tr>
#       <td>ミカドWORLD店</td>
#       <td>マキシマムスロッター</td>
#       <td>パチンコ店長のホール攻略</td>
#       <td>未調査</td>
#     </tr>
#     <tr>
#       <td>ミカドWORLD店</td>
#       <td>IMCいむちゃんねる 収録予定</td>
#       <td>IMCいむちゃんねる</td>
#       <td>未調査</td>
#     </tr>
#     <tr>
#       <td>インディ刈谷店</td>
#       <td>ゲンキー実践取材</td>
#       <td>スロスタ</td>
#       <td>未調査</td>
#     </tr>
#     <tr>
#       <td>インディ刈谷店</td>
#       <td>シューティングスター</td>
#       <td>未調査</td>
#       <td>未調査</td>
#     </tr>
#     <tr>
#       <td>ラッキープラザ1111弥富店</td>
#       <td>求道者取材</td>
#       <td>でちゃう！</td>
#       <td>未調査</td>
#     </tr>
#     <tr>
#       <td>ラッキープラザ1111弥富店</td>
#       <td>旧イベ(9のつく日)</td>
#       <td>旧イベ</td>
#       <td>未調査</td>
#     </tr>
#     <tr>
#       <td>ミカド稲沢店</td>
#       <td>マキシマムスロッター</td>
#       <td>パチンコ店長のホール攻略</td>
#       <td>未調査</td>
#     </tr>
#     <tr>
#       <td>ラッキープラザ大府店</td>
#       <td>ナイン×スロッター</td>
#       <td>パチンコ店長のホール攻略</td>
#       <td>未調査</td>
#     </tr>
#     <tr>
#       <td>ラッキープラザ大府店</td>
#       <td>旧イベ(9のつく日)</td>
#       <td>旧イベ</td>
#       <td>未調査</td>
#     </tr>
#     <tr>
#       <td>MEGAコンコルド1280稲沢店</td>
#       <td>スロッター×パチンカー</td>
#       <td>パチンコ店長のホール攻略</td>
#       <td>スロッター×2とパチンカー×2の同時開催</td>
#     </tr>
#     <tr>
#       <td>PAO共和店</td>
#       <td>スロッター×パチンカー</td>
#       <td>パチンコ店長のホール攻略</td>
#       <td>スロッター×2とパチンカー×2の同時開催</td>
#     </tr>
#     <tr>
#       <td>メガスロットコンコルド345吉浜店</td>
#       <td>スロッター×スロッターSMART</td>
#       <td>パチンコ店長のホール攻略</td>
#       <td>未調査</td>
#     </tr>
#     <tr>
#       <td>メガスロットコンコルド345吉浜店</td>
#       <td>スロッター×スロッター6.5</td>
#       <td>パチンコ店長のホール攻略</td>
#       <td>未調査</td>
#     </tr>
#     <tr>
#       <td>KYORAKU 西店</td>
#       <td>旧イベ(9のつく日)</td>
#       <td>旧イベ</td>
#       <td>未調査</td>
#     </tr>
#     <tr>
#       <td>ミカド一宮本店</td>
#       <td>マキシマムスロッター</td>
#       <td>パチンコ店長のホール攻略</td>
#       <td>未調査</td>
#     </tr>
#     <tr>
#       <td>G&amp;L一宮店</td>
#       <td>パチンカー×パチンカー</td>
#       <td>パチンコ店長のホール攻略</td>
#       <td>パチンコ2機種以上で分岐営業\r\n　　　対象機種はHP要確認</td>
#     </tr>
#     <tr>
#       <td>G&amp;L一宮店</td>
#       <td>ズバパチミレニアム</td>
#       <td>あかだ主任のガチンコ…</td>
#       <td>未調査</td>
#     </tr>
#     <tr>
#       <td>ラッキープラザ津島店</td>
#       <td>必勝本ライター来店情報</td>
#       <td>パチスロ必勝本</td>
#       <td>来店実践</td>
#     </tr>
#     <tr>
#       <td>ラッキープラザ津島店</td>
#       <td>求道者取材</td>
#       <td>でちゃう！</td>
#       <td>未調査</td>
#     </tr>
#     <tr>
#       <td>ラッキープラザ津島店</td>
#       <td>旧イベ(9のつく日)</td>
#       <td>旧イベ</td>
#       <td>未調査</td>
#     </tr>
#     <tr>
#       <td>ZENT稲沢店</td>
#       <td>スロッター×スロッター</td>
#       <td>パチンコ店長のホール攻略</td>
#       <td>4つの公約が存在。要HPチェック</td>
#     </tr>
#     <tr>
#       <td>キャッスル大金店</td>
#       <td>マキシマムスロッター</td>
#       <td>パチンコ店長のホール攻略</td>
#       <td>未調査</td>
#     </tr>
#     <tr>
#       <td>プレイランド第一平和</td>
#       <td>パチンカー×パチンカー</td>
#       <td>パチンコ店長のホール攻略</td>
#       <td>パチンコ2機種以上で分岐営業\r\n　　　対象機種はHP要確認</td>
#     </tr>
#     <tr>
#       <td>キャッスル岩倉店</td>
#       <td>マキシマムスロッター</td>
#       <td>パチンコ店長のホール攻略</td>
#       <td>未調査</td>
#     </tr>
#   </tbody>
# </table>
# C:\Users\tsc95\AppData\Local\Temp\ipykernel_6584\1440840221.py:193: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   html_table_df['イベント日'] = self.target_date_string_jp
# Not found: パチンコ店長のホール攻略 http://slotana777.com/wp-content/uploads/2023/04/%E3%83%91%E3%83%81%E3%83%B3%E3%82%B3%E5%BA%97%E9%95%B7%E3%81%AE%E3%83%9B%E3%83%BC%E3%83%AB%E6%94%BB%E7%95%A5.jpg
# Not found: 旧イベ http://slotana777.com/wp-content/uploads/2023/04/%E6%97%A7%E3%82%A4%E3%83%99.jpg
# Not found: アツ姫 http://slotana777.com/wp-content/uploads/2023/04/%E3%82%A2%E3%83%84%E5%A7%AB.jpg
# Not found: スロパチステーション http://slotana777.com/wp-content/uploads/2023/04/%E3%82%B9%E3%83%AD%E3%83%91%E3%83%81%E3%82%B9%E3%83%86%E3%83%BC%E3%82%B7%E3%83%A7%E3%83%B3.jpg
# Not found: でちゃう！ http://slotana777.com/wp-content/uploads/2023/04/%E3%81%A7%E3%81%A1%E3%82%83%E3%81%86%EF%BC%81.jpg
# Not found: オフミー http://slotana777.com/wp-content/uploads/2023/04/%E3%82%AA%E3%83%95%E3%83%9F%E3%83%BC.jpg
# Not found: その他取材・企画 http://slotana777.com/wp-content/uploads/2023/04/%E3%81%9D%E3%81%AE%E4%BB%96%E5%8F%96%E6%9D%90%E3%83%BB%E4%BC%81%E7%94%BB.jpg
# Not found: リアルガチホール http://slotana777.com/wp-content/uploads/2023/04/%E3%83%AA%E3%82%A2%E3%83%AB%E3%82%AC%E3%83%81%E3%83%9B%E3%83%BC%E3%83%AB.jpg
# Not found: IMCいむちゃんねる http://slotana777.com/wp-content/uploads/2023/04/IMC%E3%81%84%E3%82%80%E3%81%A1%E3%82%83%E3%82%93%E3%81%AD%E3%82%8B.jpg
# Not found: スロスタ http://slotana777.com/wp-content/uploads/2023/04/%E3%82%B9%E3%83%AD%E3%82%B9%E3%82%BF.jpg
# Not found: あかだ主任のガチンコ… http://slotana777.com/wp-content/uploads/2023/04/%E3%81%82%E3%81%8B%E3%81%A0%E4%B8%BB%E4%BB%BB%E3%81%AE%E3%82%AC%E3%83%81%E3%83%B3%E3%82%B3%E2%80%A6.jpg
# Not found: 未調査 http://slotana777.com/wp-content/uploads/2023/04/%E6%9C%AA%E8%AA%BF%E6%9F%BB.jpg
#
#
# <div class="box-alert box-alert-info">
#         <i class="fas fa-exclamation-circle fa-4x"></i>
#         <div class="alert-message">
#             <div class="alert-title">パチンコ店長のホール攻略</div>
#             <p>4月9日(日)  愛知県</p>
#         </div></div><div class="redbox"><h5><span class="oomozi"><strong>サプライズスロッター</strong></span></h5>
#
# <span class="hatenamark2 on-color">公約:未調査</span>
# <h4 class="rankh4 rankno-2"> メガコンコルド800春日井店+</strong></span></h4>
# <h4 class="rankh4 rankno-2"> コンコルド880愛西日比野駅前店</strong></span></h4>
# <h4 class="rankh4 rankno-2"> キング666一宮店</strong></span></h4></div><div class="redbox"><h5><span class="oomozi"><strong>マキシマムスロッター</strong></span></h5>
#
# <span class="hatenamark2 on-color">公約:未調査</span>
# <h4 class="rankh4 rankno-3"> ミカド一宮インター店</strong></span></h4>
# <h4 class="rankh4 rankno-3"> ミカドWORLD店</strong></span></h4>
# <h4 class="rankh4 rankno-3"> ミカド稲沢店</strong></span></h4>
# <h4 class="rankh4 rankno-3"> ミカド一宮本店</strong></span></h4>
# <h4 class="rankh4 rankno-3"> キャッスル大金店</strong></span></h4>
# <h4 class="rankh4 rankno-3"> キャッスル岩倉店</strong></span></h4></div><div class="redbox"><h5><span class="oomozi"><strong>パチンカー×パチンカー</strong></span></h5>
#
# <span class="hatenamark2 on-color">公約:パチンコ2機種以上で分岐営業
# 　　　対象機種はHP要確認</span>
# <h4 class="rankh4 rankno-4"> メガコンコルド555西尾店</strong></span></h4>
# <h4 class="rankh4 rankno-4"> G&L一宮店</strong></span></h4>
# <h4 class="rankh4 rankno-4"> プレイランド第一平和</strong></span></h4></div><div class="redbox"><h5><span class="oomozi"><strong>スロッター×スロッターSMART</strong></span></h5>
#
# <span class="hatenamark2 on-color">公約:未調査</span>
# <h4 class="rankh4 rankno-4"> メガスロットコンコルド345吉浜店</strong></span></h4></div><div class="redbox"><h5><span class="oomozi"><strong>スロッター×スロッター</strong></span></h5>
#
# <span class="hatenamark2 on-color">公約:4つの公約が存在。要HPチェック</span>
# <h4 class="rankh4 rankno-4"> イクサム岡崎西店</strong></span></h4>
# <h4 class="rankh4 rankno-4"> イクサム甚目寺店</strong></span></h4>
# <h4 class="rankh4 rankno-4"> プレイランド平和大治店</strong></span></h4>
# <h4 class="rankh4 rankno-4"> コンコルド800 一宮尾西インター店</strong></span></h4>
# <h4 class="rankh4 rankno-4"> ZENT稲沢店</strong></span></h4></div><div class="redbox"><h5><span class="oomozi"><strong>スロッター×スロッター6.5</strong></span></h5>
#
# <span class="hatenamark2 on-color">公約:未調査</span>
# <h4 class="rankh4 rankno-4"> メガコンコルド555西尾店</strong></span></h4>
# <h4 class="rankh4 rankno-4"> メガスロットコンコルド345吉浜店</strong></span></h4></div><div class="redbox"><h5><span class="oomozi"><strong>ナイン×スロッター</strong></span></h5>
#
# <span class="hatenamark2 on-color">公約:未調査</span>
# <h4 class="rankh4 rankno-4"> ラッキープラザ大府店</strong></span></h4></div><div class="redbox"><h5><span class="oomozi"><strong>スロッター×パチンカー</strong></span></h5>
#
# <span class="hatenamark2 on-color">公約:スロッター×2とパチンカー×2の同時開催</span>
# <h4 class="rankh4 rankno-4"> MEGAコンコルド1280稲沢店</strong></span></h4>
# <h4 class="rankh4 rankno-4"> PAO共和店</strong></span></h4></div>
# <div class="box-alert box-alert-info">
#         <i class="fas fa-exclamation-circle fa-4x"></i>
#         <div class="alert-message">
#             <div class="alert-title">旧イベ</div>
#             <p>4月9日(日)  愛知県</p>
#         </div></div><div class="redbox"><h5><span class="oomozi"><strong>旧イベ(9のつく日)</strong></span></h5>
#
# <span class="hatenamark2 on-color">公約:未調査</span>
# <h4 class="rankh4 rankno-4"> ラッキープラザ名古屋西インター七宝店</strong></span></h4>
# <h4 class="rankh4 rankno-4"> メガガイア一宮</strong></span></h4>
# <h4 class="rankh4 rankno-4"> イクサム岡崎西店</strong></span></h4>
# <h4 class="rankh4 rankno-4"> イクサム甚目寺店</strong></span></h4>
# <h4 class="rankh4 rankno-4"> ラッキープラザ1111弥富店</strong></span></h4>
# <h4 class="rankh4 rankno-4"> ラッキープラザ大府店</strong></span></h4>
# <h4 class="rankh4 rankno-4"> KYORAKU 西店</strong></span></h4>
# <h4 class="rankh4 rankno-4"> ラッキープラザ津島店</strong></span></h4></div>
# <div class="box-alert box-alert-info">
#         <i class="fas fa-exclamation-circle fa-4x"></i>
#         <div class="alert-message">
#             <div class="alert-title">アツ姫</div>
#             <p>4月9日(日)  愛知県</p>
#         </div></div><div class="redbox"><h5><span class="oomozi"><strong>プレミアムジャッジメントP</strong></span></h5>
#
# <span class="hatenamark2 on-color">公約:未調査</span>
# <h4 class="rankh4 rankno-3"> 京楽会館 豊明店</strong></span></h4>
# <h4 class="rankh4 rankno-3"> メガコンコルド1220みなと23号通り店</strong></span></h4></div><div class="redbox"><h5><span class="oomozi"><strong>プレミアムジャッジメントS</strong></span></h5>
#
# <span class="hatenamark2 on-color">公約:未調査</span>
# <h4 class="rankh4 rankno-4"> 京楽会館 豊明店</strong></span></h4></div>
# <div class="box-alert box-alert-info">
#         <i class="fas fa-exclamation-circle fa-4x"></i>
#         <div class="alert-message">
#             <div class="alert-title">スロパチステーション</div>
#             <p>4月9日(日)  愛知県</p>
#         </div></div><div class="redbox"><h5><span class="oomozi"><strong>かたまる×スロパチステーション潜入取材 結</strong></span></h5>
#
# <span class="hatenamark2 on-color">公約:未調査</span>
# <h4 class="rankh4 rankno-1"> メガガイア一宮</strong></span></h4></div><div class="redbox"><h5><span class="oomozi"><strong>潜入取材ギガテン</strong></span></h5>
#
# <span class="hatenamark2 on-color">公約:未調査</span>
# <h4 class="rankh4 rankno-2"> メガコンコルド1111BLAZE店</strong></span></h4></div>
# <div class="box-alert box-alert-info">
#         <i class="fas fa-exclamation-circle fa-4x"></i>
#         <div class="alert-message">
#             <div class="alert-title">でちゃう！</div>
#             <p>4月9日(日)  愛知県</p>
#         </div></div><div class="redbox"><h5><span class="oomozi"><strong>超HiTension取材</strong></span></h5>
#
# <span class="hatenamark2 on-color">公約:未調査</span>
# <h4 class="rankh4 rankno-2"> マルシン東刈谷店</strong></span></h4></div><div class="redbox"><h5><span class="oomozi"><strong>でちゃう編集部来店(かおりん)</strong></span></h5>
#
# <span class="hatenamark2 on-color">公約:未調査</span>
# <h4 class="rankh4 rankno-4"> マルシン東刈谷店</strong></span></h4></div><div class="redbox"><h5><span class="oomozi"><strong>カリスマ取材</strong></span></h5>
#
# <span class="hatenamark2 on-color">公約:未調査</span>
# <h4 class="rankh4 rankno-4"> メガコンコルド555西尾店</strong></span></h4></div><div class="redbox"><h5><span class="oomozi"><strong>求道者取材</strong></span></h5>
#
# <span class="hatenamark2 on-color">公約:未調査</span>
# <h4 class="rankh4 rankno-4"> ラッキープラザ1111弥富店</strong></span></h4>
# <h4 class="rankh4 rankno-4"> ラッキープラザ津島店</strong></span></h4></div>
# <div class="box-alert box-alert-info">
#         <i class="fas fa-exclamation-circle fa-4x"></i>
#         <div class="alert-message">
#             <div class="alert-title">オフミー</div>
#             <p>4月9日(日)  愛知県</p>
#         </div></div><div class="redbox"><h5><span class="oomozi"><strong>オフミー取材</strong></span></h5>
#
# <span class="hatenamark2 on-color">公約:全台形が数カ所入りやすい</span>
# <h4 class="rankh4 rankno-4"> キング観光サウザンド名古屋駅柳橋店</strong></span></h4></div><div class="redbox"><h5><span class="oomozi"><strong>スマートオフミー(初開催)</strong></span></h5>
#
# <span class="hatenamark2 on-color">公約:未調査</span>
# <h4 class="rankh4 rankno-4"> メガコンコルド1220みなと23号通り店</strong></span></h4></div><div class="redbox"><h5><span class="oomozi"><strong>パチミー取材</strong></span></h5>
#
# <span class="hatenamark2 on-color">公約:未調査</span>
# <h4 class="rankh4 rankno-4"> キング観光サウザンド名古屋駅柳橋店</strong></span></h4></div>
# <div class="box-alert box-alert-info">
#         <i class="fas fa-exclamation-circle fa-4x"></i>
#         <div class="alert-message">
#             <div class="alert-title">その他取材・企画</div>
#             <p>4月9日(日)  愛知県</p>
#         </div></div><div class="redbox"><h5><span class="oomozi"><strong>魔法ちゃん来店</strong></span></h5>
#
# <span class="hatenamark2 on-color">公約:未調査</span>
# <h4 class="rankh4 rankno-3"> GOGO千代田</strong></span></h4></div>
# <div class="box-alert box-alert-info">
#         <i class="fas fa-exclamation-circle fa-4x"></i>
#         <div class="alert-message">
#             <div class="alert-title">リアルガチホール</div>
#             <p>4月9日(日)  愛知県</p>
#         </div></div><div class="redbox"><h5><span class="oomozi"><strong>ガチスロ</strong></span></h5>
#
# <span class="hatenamark2 on-color">公約:未調査</span>
# <h4 class="rankh4 rankno-4"> KEIZ大高店</strong></span></h4></div>
# <div class="box-alert box-alert-info">
#         <i class="fas fa-exclamation-circle fa-4x"></i>
#         <div class="alert-message">
#             <div class="alert-title">IMCいむちゃんねる</div>
#             <p>4月9日(日)  愛知県</p>
#         </div></div><div class="redbox"><h5><span class="oomozi"><strong>IMCいむちゃんねる 収録予定</strong></span></h5>
#
# <span class="hatenamark2 on-color">公約:未調査</span>
# <h4 class="rankh4 rankno-4"> ミカドWORLD店</strong></span></h4></div>
# <div class="box-alert box-alert-info">
#         <i class="fas fa-exclamation-circle fa-4x"></i>
#         <div class="alert-message">
#             <div class="alert-title">スロスタ</div>
#             <p>4月9日(日)  愛知県</p>
#         </div></div><div class="redbox"><h5><span class="oomozi"><strong>ゲンキー実践取材</strong></span></h5>
#
# <span class="hatenamark2 on-color">公約:未調査</span>
# <h4 class="rankh4 rankno-3"> インディ刈谷店</strong></span></h4></div>
# <div class="box-alert box-alert-info">
#         <i class="fas fa-exclamation-circle fa-4x"></i>
#         <div class="alert-message">
#             <div class="alert-title">あかだ主任のガチンコ…</div>
#             <p>4月9日(日)  愛知県</p>
#         </div></div><div class="redbox"><h5><span class="oomozi"><strong>ズバパチミレニアム</strong></span></h5>
#
# <span class="hatenamark2 on-color">公約:未調査</span>
# <h4 class="rankh4 rankno-4"> G&L一宮店</strong></span></h4></div><img src="http://slotana777.com/wp-content/uploads/2023/04/パチスロ必勝本.jpg" alt="パチスロ必勝本" width="1000" height="400" class="size-full " />
# <div class="redbox"><h5><span class="oomozi"><strong>必勝本ライター来店情報</strong></span></h5>
#
# <span class="hatenamark2 on-color">公約:来店実践</span>
# <h4 class="rankh4 rankno-4"> ラッキープラザ津島店</strong></span></h4></div>
# <div class="box-alert box-alert-info">
#         <i class="fas fa-exclamation-circle fa-4x"></i>
#         <div class="alert-message">
#             <div class="alert-title">未調査</div>
#             <p>4月9日(日)  愛知県</p>
#         </div></div><div class="redbox"><h5><span class="oomozi"><strong>シューティングスター</strong></span></h5>
#
# <span class="hatenamark2 on-color">公約:未調査</span>
# <h4 class="rankh4 rankno-3"> インディ刈谷店</strong></span></h4></div><div class="redbox"><h5><span class="oomozi"><strong>ガチパチ</strong></span></h5>
#
# <span class="hatenamark2 on-color">公約:未調査</span>
# <h4 class="rankh4 rankno-4"> KEIZ大高店</strong></span></h4></div>
# image\temp_image\thumbnail_2023-04-09_愛知県.jpg Upload Success : id=39179
# 記事書き込み完了

# %%
list(merged_syuzai_pledge_df['媒体名'].unique())
# Out:
# ['オフミー',
#  'ガチアン',
#  'スロパチステーション',
#  'ジャンバリ.TV',
#  'パチンコ店長のホール攻略',
#  'でちゃう！',
#  '旧イベ',
#  'DMMぱちタウン',
#  'Gooパチ',
#  'ダブルジャッジ',
#  'アツ姫',
#  'ななライズ',
#  'その他取材・企画',
#  'あかだ主任のガチンコ…',
#  'リニューアルオープン',
#  'dorislo',
#  'ドリスロ']

# %%
blog.wp_update_post(update_content_id, main_text )
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File c:\Users\tsc95\Desktop\syuzai_map_django_site\venv\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File c:\Users\tsc95\Desktop\syuzai_map_django_site\venv\lib\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# File <string>:3, in raise_from(value, from_value)
#
# File c:\Users\tsc95\Desktop\syuzai_map_django_site\venv\lib\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443 try:
# --> 444     httplib_response = conn.getresponse()
#     445 except BaseException as e:
#     446     # Remove the TypeError from the exception chain in
#     447     # Python 3 (including for exceptions like SystemExit).
#     448     # Otherwise it looks like a bug in the code.
#
# File ~\anaconda3\lib\http\client.py:1377, in HTTPConnection.getresponse(self)
#    1376 try:
# -> 1377     response.begin()
#    1378 except ConnectionError:
#
# File ~\anaconda3\lib\http\client.py:320, in HTTPResponse.begin(self)
#     319 while True:
# --> 320     version, status, reason = self._read_status()
#     321     if status != CONTINUE:
#
# File ~\anaconda3\lib\http\client.py:281, in HTTPResponse._read_status(self)
#     280 def _read_status(self):
# --> 281     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282     if len(line) > _MAXLINE:
#
# File ~\anaconda3\lib\socket.py:704, in SocketIO.readinto(self, b)
#     703 try:
# --> 704     return self._sock.recv_into(b)
#     705 except timeout:
#
# File ~\anaconda3\lib\ssl.py:1242, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1239         raise ValueError(
#    1240           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1241           self.__class__)
# -> 1242     return self.read(nbytes, buffer)
#    1243 else:
#
# File ~\anaconda3\lib\ssl.py:1100, in SSLSocket.read(self, len, buffer)
#    1099 if buffer is not None:
# -> 1100     return self._sslobj.read(len, buffer)
#    1101 else:
#
# ConnectionResetError: [WinError 10054] 既存の接続はリモート ホストに強制的に切断されました。
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# File c:\Users\tsc95\Desktop\syuzai_map_django_site\venv\lib\site-packages\requests\adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     488 if not chunked:
# --> 489     resp = conn.urlopen(
#     490         method=request.method,
#     491         url=url,
#     492         body=request.body,
#     493         headers=request.headers,
#     494         redirect=False,
#     495         assert_same_host=False,
#     496         preload_content=False,
#     497         decode_content=False,
#     498         retries=self.max_retries,
#     499         timeout=timeout,
#     500     )
#     502 # Send the request.
#     503 else:
#
# File c:\Users\tsc95\Desktop\syuzai_map_django_site\venv\lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     785     e = ProtocolError("Connection aborted.", e)
# --> 787 retries = retries.increment(
#     788     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     789 )
#     790 retries.sleep()
#
# File c:\Users\tsc95\Desktop\syuzai_map_django_site\venv\lib\site-packages\urllib3\util\retry.py:550, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     549 if read is False or not self._is_method_retryable(method):
# --> 550     raise six.reraise(type(error), error, _stacktrace)
#     551 elif read is not None:
#
# File c:\Users\tsc95\Desktop\syuzai_map_django_site\venv\lib\site-packages\urllib3\packages\six.py:769, in reraise(tp, value, tb)
#     768 if value.__traceback__ is not tb:
# --> 769     raise value.with_traceback(tb)
#     770 raise value
#
# File c:\Users\tsc95\Desktop\syuzai_map_django_site\venv\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File c:\Users\tsc95\Desktop\syuzai_map_django_site\venv\lib\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# File <string>:3, in raise_from(value, from_value)
#
# File c:\Users\tsc95\Desktop\syuzai_map_django_site\venv\lib\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443 try:
# --> 444     httplib_response = conn.getresponse()
#     445 except BaseException as e:
#     446     # Remove the TypeError from the exception chain in
#     447     # Python 3 (including for exceptions like SystemExit).
#     448     # Otherwise it looks like a bug in the code.
#
# File ~\anaconda3\lib\http\client.py:1377, in HTTPConnection.getresponse(self)
#    1376 try:
# -> 1377     response.begin()
#    1378 except ConnectionError:
#
# File ~\anaconda3\lib\http\client.py:320, in HTTPResponse.begin(self)
#     319 while True:
# --> 320     version, status, reason = self._read_status()
#     321     if status != CONTINUE:
#
# File ~\anaconda3\lib\http\client.py:281, in HTTPResponse._read_status(self)
#     280 def _read_status(self):
# --> 281     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282     if len(line) > _MAXLINE:
#
# File ~\anaconda3\lib\socket.py:704, in SocketIO.readinto(self, b)
#     703 try:
# --> 704     return self._sock.recv_into(b)
#     705 except timeout:
#
# File ~\anaconda3\lib\ssl.py:1242, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1239         raise ValueError(
#    1240           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1241           self.__class__)
# -> 1242     return self.read(nbytes, buffer)
#    1243 else:
#
# File ~\anaconda3\lib\ssl.py:1100, in SSLSocket.read(self, len, buffer)
#    1099 if buffer is not None:
# -> 1100     return self._sslobj.read(len, buffer)
#    1101 else:
#
# ProtocolError: ('Connection aborted.', ConnectionResetError(10054, '既存の接続はリモート ホストに強制的に切断されました。', None, 10054, None))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 blog.wp_update_post(update_content_id, main_text )
#
# Cell In[17], line 139, in Blog.wp_update_post(self, content_id, changed_content)
#     134 url = f'{WP_URL}/wp-json/wp/v2/posts/{content_id}'
#     137 params = {'content':changed_content}
# --> 139 res = requests.post(
#     140     url,
#     141     params=params,
#     142     auth=( WP_USER, WP_API_PASSWORD),
#     143     )
#     145 return res
#
# File c:\Users\tsc95\Desktop\syuzai_map_django_site\venv\lib\site-packages\requests\api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File c:\Users\tsc95\Desktop\syuzai_map_django_site\venv\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\tsc95\Desktop\syuzai_map_django_site\venv\lib\site-packages\requests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File c:\Users\tsc95\Desktop\syuzai_map_django_site\venv\lib\site-packages\requests\sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File c:\Users\tsc95\Desktop\syuzai_map_django_site\venv\lib\site-packages\requests\adapters.py:547, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     544             raise
#     546 except (ProtocolError, OSError) as err:
# --> 547     raise ConnectionError(err, request=request)
#     549 except MaxRetryError as e:
#     550     if isinstance(e.reason, ConnectTimeoutError):
#     551         # TODO: Remove this in 3.0.0: see #2811
#
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, '既存の接続はリモート ホストに強制的に切断されました。', None, 10054, None))

# %%
len(main_text)
# Out:
# 8351

# %%
main_text


def wp_update_post(content_id:int, main_text):

    # URL, User, Password設定
    WP_URL: str = os.getenv('WP_URL')
    WP_USER: str = os.getenv('WP_USER')
    WP_API_PASSWORD: str = os.getenv('REST_API_PW')
    API_URL = f"{WP_URL}/wp-json/wp/v2/"
    url = f'{WP_URL}/wp-json/wp/v2/posts/{content_id}'


    post = {'content': main_text}

    res = requests.post(
        url,
        params=post,
        auth=( WP_USER, WP_API_PASSWORD),
        )

    return res


wp_update_post(38619, main_text)
# Out:
# <Response [414]>

# %%
import requests
import json
import base64
# Out:
# 投稿の更新 成功 code:{res.status_code}
# {'id': 38619,
#  'date': '2023-04-03T23:52:44',
#  'date_gmt': '2023-04-03T14:52:44',
#  'guid': {'rendered': 'https://slotana777.com/?p=38619',
#   'raw': 'https://slotana777.com/?p=38619'},
#  'modified': '2023-04-03T23:52:44',
#  'modified_gmt': '2023-04-03T14:52:44',
#  'password': '',
#  'slug': '',
#  'status': 'draft',
#  'type': 'post',
#  'link': 'https://slotana777.com/?p=38619',
#  'title': {'raw': '', 'rendered': ''},
#  'content': {'raw': '\n[st-kaiwa1]【愛知県】4月4日(火)\u3000パチンコホールイベント取材まとめ記事です。\n\nイベントの公約に基づき、高設定が投入される可能性が高いと予想されるホールを中心に公約内容も一緒にわかりやすく明日のイベントのある店舗を紹介しています。\n\n毎日更新されますので是非、ブックマークお願いします。[/st-kaiwa1]\n<h3>更新時間:04月03日23時04分</h3>\n<h2>愛知県  パチンコ・スロット イベント 取材まとめ・オススメ店舗順一覧画像</h2>\n\n<a href="http://slotana777.com/wp-content/uploads/2023/04/eva_board_愛知県_2023-04-04_1_updatetime_04-03.jpg">\n<img src="http://slotana777.com/wp-content/uploads/2023/04/eva_board_愛知県_2023-04-04_1_updatetime_04-03.jpg" alt="愛知県_2023-04-04_パチンコ・パチスロ_イベント" class="alignnone size-full " /></a>\n<a href="http://slotana777.com/wp-content/uploads/2023/04/eva_board_愛知県_2023-04-04_2_updatetime_04-03.jpg">\n<img src="http://slotana777.com/wp-content/uploads/2023/04/eva_board_愛知県_2023-04-04_2_updatetime_04-03.jpg" alt="愛知県_2023-04-04_パチンコ・パチスロ_イベント" class="alignnone size-full " /></a><h2>愛知県 4月4日(火) パチンコ・スロット イベント 取材まとめ・オススメ店舗順一覧</h2>\n<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th>店舗名</th>\n      <th>取材名</th>\n      <th>媒体名</th>\n      <th>公約内容</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <td>メガコンコルド800春日井店+</td>\n      <td>寿司投げ</td>\n      <td>未調査</td>\n      <td>未調査</td>\n    </tr>\n    <tr>\n      <td>メガコンコルド800春日井店+</td>\n      <td>ダブジャクエスト(初)</td>\n      <td>ダブルジャッジ</td>\n      <td>未調査</td>\n    </tr>\n    <tr>\n      <td>コンコルド880愛西日比野駅前店</td>\n      <td>超りゅーこ広告</td>\n      <td>りゅーこ</td>\n      <td>未調査</td>\n    </tr>\n    <tr>\n      <td>メガコンコルド1020刈谷知立店</td>\n      <td>ズバスロ</td>\n      <td>あかだ主任のガチンコ…</td>\n      <td>未調査</td>\n    </tr>\n    <tr>\n      <td>M&amp;K岡崎店</td>\n      <td>てんぴー来店</td>\n      <td>その他取材・企画</td>\n      <td>未調査</td>\n    </tr>\n    <tr>\n      <td>GOLD 玉越 本店</td>\n      <td>THE新台入替</td>\n      <td>DMMぱちタウン</td>\n      <td>未調査</td>\n    </tr>\n    <tr>\n      <td>マルハン新守山駅前店</td>\n      <td>旧イベ(月と重なる日)</td>\n      <td>旧イベ</td>\n      <td>未調査</td>\n    </tr>\n    <tr>\n      <td>ラッキープラザ1111弥富店</td>\n      <td>りゅーこ広告</td>\n      <td>りゅーこ</td>\n      <td>未調査</td>\n    </tr>\n    <tr>\n      <td>ラッキープラザ1111弥富店</td>\n      <td>リニューアル(2日目)</td>\n      <td>リニューアルオープン</td>\n      <td>未調査</td>\n    </tr>\n    <tr>\n      <td>MEGAコンコルド豊川インター店</td>\n      <td>新台入替(P-WORLD引用)</td>\n      <td>新台入替</td>\n      <td>未調査</td>\n    </tr>\n    <tr>\n      <td>名宝刈谷店</td>\n      <td>旧イベ(4のつく日)</td>\n      <td>旧イベ</td>\n      <td>未調査</td>\n    </tr>\n    <tr>\n      <td>メガコンコルド1220みなと23号通り店</td>\n      <td>新台入替(P-WORLD引用)</td>\n      <td>新台入替</td>\n      <td>未調査</td>\n    </tr>\n    <tr>\n      <td>ミカドWORLD店</td>\n      <td>旧イベ(4のつく日)</td>\n      <td>旧イベ</td>\n      <td>未調査</td>\n    </tr>\n    <tr>\n      <td>メガガイア一宮</td>\n      <td>リニューアル(2日目)</td>\n      <td>リニューアルオープン</td>\n      <td>未調査</td>\n    </tr>\n    <tr>\n      <td>G&amp;L一宮店</td>\n      <td>スロパチなごや嬢すみれ来店</td>\n      <td>その他取材・企画</td>\n      <td>未調査</td>\n    </tr>\n    <tr>\n      <td>G&amp;L一宮店</td>\n      <td>右京来店</td>\n      <td>その他取材・企画</td>\n      <td>未調査</td>\n    </tr>\n    <tr>\n      <td>G&amp;L一宮店</td>\n      <td>ブラックサンダーG&amp;</td>\n      <td>あかだ主任のガチンコ…</td>\n      <td>未調査</td>\n    </tr>\n    <tr>\n      <td>名宝大清水店</td>\n      <td>旧イベ(4のつく日)</td>\n      <td>旧イベ</td>\n      <td>未調査</td>\n    </tr>\n    <tr>\n      <td>ダイマル星崎店</td>\n      <td>エース小吉来店</td>\n      <td>その他取材・企画</td>\n      <td>未調査</td>\n    </tr>\n    <tr>\n      <td>名宝岡崎店</td>\n      <td>旧イベ(4のつく日)</td>\n      <td>旧イベ</td>\n      <td>未調査</td>\n    </tr>\n    <tr>\n      <td>メガコンコルド1111BLAZE店</td>\n      <td>ダブジャクエスト(初)</td>\n      <td>ダブルジャッジ</td>\n      <td>未調査</td>\n    </tr>\n  </tbody>\n</table>\n\n<div class="box-alert box-alert-info">\n        <i class="fas fa-exclamation-circle fa-4x"></i>\n        <div class="alert-message">\n            <div class="alert-title">ダブルジャッジ</div>\n            <p>4月4日(火)  愛知県</p>\n        </div></div><h4>ダブジャクエスト(初)</h4>\n・メガコンコルド800春日井店+\n・メガコンコルド1111BLAZE店\n\n<div class="box-alert box-alert-info">\n        <i class="fas fa-exc ...
#   'rendered': '<div class="st-kaiwa-box kaiwaicon1 clearfix"><div class="st-kaiwa-face"><img src="http://slotana777.com/wp-content/uploads/2020/09/スクリーンショット-2020-09-22-0.16.10-295x300.png" width="60px"><div class="st-kaiwa-face-name">赤坂</div></div><div class="st-kaiwa-area"><div class="st-kaiwa-hukidashi">【愛知県】4月4日(火)\u3000パチンコホールイベント取材まとめ記事です。</p>\n<p>イベントの公約に基づき、高設定が投入される可能性が高いと予想されるホールを中心に公約内容も一緒にわかりやすく明日のイベントのある店舗を紹介しています。</p>\n<p>毎日更新されますので是非、ブックマークお願いします。</div></div></div>\n<h3>更新時間:04月03日23時04分</h3>\n<h2>愛知県  パチンコ・スロット イベント 取材まとめ・オススメ店舗順一覧画像</h2>\n<p><a href="http://slotana777.com/wp-content/uploads/2023/04/eva_board_愛知県_2023-04-04_1_updatetime_04-03.jpg"><br />\n<img src="http://slotana777.com/wp-content/uploads/2023/04/eva_board_愛知県_2023-04-04_1_updatetime_04-03.jpg" alt="愛知県_2023-04-04_パチンコ・パチスロ_イベント" class="alignnone size-full " /></a><br />\n<a href="http://slotana777.com/wp-content/uploads/2023/04/eva_board_愛知県_2023-04-04_2_updatetime_04-03.jpg"><br />\n<img src="http://slotana777.com/wp-content/uploads/2023/04/eva_board_愛知県_2023-04-04_2_updatetime_04-03.jpg" alt="愛知県_2023-04-04_パチンコ・パチスロ_イベント" class="alignnone size-full " /></a></p>\n<h2>愛知県 4月4日(火) パチンコ・スロット イベント 取材まとめ・オススメ店舗順一覧</h2>\n<table border="1" class="dataframe">\n<thead>\n<tr style="text-align: right;">\n<th>店舗名</th>\n<th>取材名</th>\n<th>媒体名</th>\n<th>公約内容</th>\n</tr>\n</thead>\n<tbody>\n<tr>\n<td>メガコンコルド800春日井店+</td>\n<td>寿司投げ</td>\n<td>未調査</td>\n<td>未調査</td>\n</tr>\n<tr>\n<td>メガコンコルド800春日井店+</td>\n<td>ダブジャクエスト(初)</td>\n<td>ダブルジャッジ</td>\n<td>未調査</td>\n</tr>\n<tr>\n<td>コンコルド880愛西日比野駅前店</td>\n<td>超りゅーこ広告</td>\n<td>りゅーこ</td>\n<td>未調査</td>\n</tr>\n<tr>\n<td>メガコンコルド1020刈谷知立店</td>\n<td>ズバスロ</td>\n<td>あかだ主任のガチンコ…</td>\n<td>未調査</td>\n</tr>\n<tr>\n<td>M&amp;K岡崎店</td>\n<td>てんぴー来店</td>\n<td>その他取材・企画</td>\n<td>未調査</td>\n</tr>\n<tr>\n<td>GOLD 玉越 本店</td>\n<td>THE新台入替</td>\n<td>DMMぱちタウン</td>\n<td>未調査</td>\n</tr>\n<tr>\n<td>マルハン新守山駅前店</td>\n<td>旧イベ(月と重なる日)</td>\n<td>旧イベ</td>\n<td>未調査</td>\n</tr>\n<tr>\n<td>ラッキープラザ1111弥富店</td>\n<td>りゅーこ広告</td>\n<td>りゅーこ</td>\n<td>未調査</td>\n</tr>\n<tr>\n<td>ラッキープラザ1111弥富店</td>\n<td>リニューアル(2日目)</td>\n<td>リニューアルオープン</td>\n<td>未調査</td>\n</tr>\n<tr>\n<td>MEGAコンコルド豊川インター店</td>\n<td>新台入替(P-WORLD引用)</td>\n<td>新台入替</td>\n<td>未調査</td>\n</tr>\n<tr>\n<td>名宝刈谷店</td>\n<td>旧イベ(4のつく日)</td>\n<td>旧イベ</td>\n<td>未調査</td>\n</tr>\n<tr>\n<td>メガコンコルド1220みなと23号通り店</td>\n<td>新台入替(P-WORLD引用)</td>\n<td>新台入替</td>\n<td>未調査</td>\n</tr>\n<tr>\n<td>ミカドWORLD店</td>\n<td>旧イベ(4のつく日)</td>\n<td>旧イベ</td>\n<td>未調査</td>\n</tr>\n<tr>\n<td>メガガイア一宮</td>\n<td>リニューアル(2日目)</td>\n<td>リニューアルオープン</td>\n<td>未調査</td>\n</tr>\n<tr>\n<td>G&amp;L一宮店</td>\n<td>スロパチなごや嬢すみれ来店</td>\n<td>その他取材・企画</td>\n<td>未調査</td>\n</tr>\n<tr>\n<td>G&amp;L一宮店</td>\n<td>右京来店</td>\n<td>その他取材・企画</td>\n<td>未調査</td>\n</tr>\n<tr>\n<td>G&amp;L一宮店</td>\n<td>ブラックサンダーG&amp;</td>\n<td>あかだ主任のガチンコ…</td>\n<td>未調査</td>\n</tr>\n<tr>\n<td>名宝大清水店</td>\n<td>旧イベ(4のつく日)</td>\n<td>旧イベ</td>\n<td>未調査</td>\n</tr>\n<tr>\n<td>ダイマル星崎店</td>\n<td>エース小吉来店</td>\n<td>その他取材・企画</td>\n<td>未調査</td>\n</tr>\n<tr>\n<td>名宝岡崎店</td>\n<td>旧イベ(4のつく日)</td>\n<td>旧イベ</td>\n<td>未調査</td>\n</tr>\n<tr>\n<td>メガコンコルド1111BLAZE店</td>\n<td>ダブジャクエスト(初)</td>\n<td>ダブルジャッジ</td>\n<td>未調査</td>\n</tr>\n</tbody>\n</table>\n<div class="box-alert box-alert-info">\n        <i class="fas fa-exclamation-circle fa-4x"></i></p>\n<div class="alert-message">\n<div class="alert-title">ダブルジャッジ</div>\n<p>4月4日(火)  愛知県</p>\n</p></div>\n</div>\n<h4>ダブジャクエスト(初)</h4>\n<p>・メガコンコルド800春日井店+<br />\n・メガコンコルド1111BLAZE店</p>\n<div class="box-alert box-alert-info">\n        <i class="fas fa-exclamation-circle fa-4x"></i></p>\n<div class="alert-message">\n<div class="alert-title">りゅーこ</div>\n<p>4月4日(火)  愛知県</p>\n</p></div>\n</div>\n<h4>超りゅーこ広告</h4>\n<p>・コンコルド880愛西日比野駅前店</p>\n<h4>りゅーこ広告</h4>\n<p>・ラッキープラザ1111弥富店</p>\n<div class="box-alert box-alert-info">\n        <i class="fas fa-exclamation-circle fa-4x"></i></p>\n<div class="alert-message">\n<div class="alert-title">あかだ主任のガチンコ…</div>\n<p>4月4日(火)  愛知県</p ...
#   'protected': False,
#   'block_version': 0},
#  'excerpt': {'raw': '',
#   'rendered': '<p>赤坂【愛知県】4月4日(火)\u3000パチンコホールイベント取材まとめ記事です。 イベントの公約に基づき、高設定が投入される可能性が高いと予想されるホールを中心に公約内容も一緒にわかりやすく明日のイベントのあ &#8230; </p>\n',
#   'protected': False},
#  'author': 2,
#  'featured_media': 225,
#  'comment_status': 'open',
#  'ping_status': 'open',
#  'sticky': False,
#  'template': '',
#  'format': 'standard',
#  'meta': {'spay_email': ''},
#  'categories': [1],
#  'tags': [],
#  'permalink_template': 'https://slotana777.com/%e6%9c%aa%e5%88%86%e9%a1%9e/%postname%/',
#  'generated_slug': '38619',
#  'jetpack_featured_media_url': 'https://slotana777.com/wp-content/uploads/2020/12/ika.png',
#  '_links': {'self': [{'href': 'https://slotana777.com/wp-json/wp/v2/posts/38619'}],
#   'collection': [{'href': 'https://slotana777.com/wp-json/wp/v2/posts'}],
#   'about': [{'href': 'https://slotana777.com/wp-json/wp/v2/types/post'}],
#   'author': [{'embeddable': True,
#     'href': 'https://slotana777.com/wp-json/wp/v2/users/2'}],
#   'replies': [{'embeddable': True,
#     'href': 'https://slotana777.com/wp-json/wp/v2/comments?post=38619'}],
#   'version-history': [{'count': 11,
#     'href': 'https://slotana777.com/wp-json/wp/v2/posts/38619/revisions'}],
#   'predecessor-version': [{'id': 39141,
#     'href': 'https://slotana777.com/wp-json/wp/v2/posts/38619/revisions/39141'}],
#   'wp:featuredmedia': [{'embeddable': True,
#     'href': 'https://slotana777.com/wp-json/wp/v2/media/225'}],
#   'wp:attachment': [{'href': 'https://slotana777.com/wp-json/wp/v2/media?parent=38619'}],
#   'wp:term': [{'taxonomy': 'category',
#     'embeddable': True,
#     'href': 'https://slotana777.com/wp-json/wp/v2/categories?post=38619'},
#    {'taxonomy': 'post_tag',
#     'embeddable': True,
#     'href': 'https://slotana777.com/wp-json/wp/v2/tags?post=38619'}],
#   'wp:action-publish': [{'href': 'https://slotana777.com/wp-json/wp/v2/posts/38619'}],
#   'wp:action-unfiltered-html': [{'href': 'https://slotana777.com/wp-json/wp/v2/posts/38619'}],
#   'wp:action-sticky': [{'href': 'https://slotana777.com/wp-json/wp/v2/posts/38619'}],
#   'wp:action-assign-author': [{'href': 'https://slotana777.com/wp-json/wp/v2/posts/38619'}],
#   'wp:action-create-categories': [{'href': 'https://slotana777.com/wp-json/wp/v2/posts/38619'}],
#   'wp:action-assign-categories': [{'href': 'https://slotana777.com/wp-json/wp/v2/posts/38619'}],
#   'wp:action-create-tags': [{'href': 'https://slotana777.com/wp-json/wp/v2/posts/38619'}],
#   'wp:action-assign-tags': [{'href': 'https://slotana777.com/wp-json/wp/v2/posts/38619'}],
#   'curies': [{'name': 'wp',
#     'href': 'https://api.w.org/{rel}',
#     'templated': True}]}}

# %%
try:
    target_dir = r'image\temp_image'
    shutil.rmtree(target_dir)
except:
    pass
finally:
    os.mkdir(target_dir)

# %%
pledge_name_list:list[str] = list(merged_syuzai_pledge_df['媒体名'].unique())
pledge_name_list.remove('未調査')
pledge_name_list.append('未調査')
pledge_name_list
# Out:
# ['スロパチステーション',
#  'アツ姫',
#  'パチンコ店長のホール攻略',
#  'その他取材・企画',
#  'Gooパチ',
#  'ジャンバリ.TV',
#  'IMCいむちゃんねる',
#  'でちゃう！',
#  'DMMぱちタウン',
#  'ダブルジャッジ',
#  'あかだ主任のガチンコ…',
#  '旧イベ',
#  '未調査']

# %%
pledge_name_list:list[str] = list(merged_syuzai_pledge_df['媒体名'].unique())
pledge_name_list.remove('未調査')
pledge_name_list.append('未調査')
pledge_name_list
# Out:
# ['ダブルジャッジ',
#  'りゅーこ',
#  'あかだ主任のガチンコ…',
#  'その他取材・企画',
#  'DMMぱちタウン',
#  '旧イベ',
#  'リニューアルオープン',
#  '新台入替',
#  '未調査']

# %%
input_pledge_text = ''




def generate_by_pledge_text(self)
    for pledge_name in pledge_name_list:
        extract_pledge_name_df = self.merged_syuzai_pledge_df[self.merged_syuzai_pledge_df['媒体名'] == pledge_name]
        encoced_plefge_name = urllib.parse.quote(pledge_name)
        header_url:str = f'http://slotana777.com/wp-content/uploads/2023/04/{encoced_plefge_name}.jpg'
        if blog.check_url(header_url,pledge_name):
            input_pledge_text += f'<img src="http://slotana777.com/wp-content/uploads/2023/04/{pledge_name}.jpg" alt="{pledge_name}" width="1000" height="400" class="size-full " />\n'
        else:
            h2_banner_text:str =f'''<div class="box-alert box-alert-info">
    <i class="fas fa-exclamation-circle fa-4x"></i>
    <div class="alert-message">
        <div class="alert-title">{pledge_name}</div>
        <p>{scraping.target_date_string_jp}  {scraping.prefecture_name}</p>
    </div></div>'''
            #print(h2_banner_text)
            input_pledge_text += '\n' + h2_banner_text
        #display(extract_pledge_name_df )
        #break
        for rank in ['S','A','B','C','・']:
            extract_syuzai_name_df  = extract_pledge_name_df[extract_pledge_name_df['取材ランク'] == rank]
            #display(extract_syuzai_name_df)
            for syuzai_name in extract_syuzai_name_df['取材名'].unique():
                input_pledge_text += '<h4>' + syuzai_name + '</h4>\n'
                extract_parlar_name_df  = extract_pledge_name_df[extract_pledge_name_df['取材名'] == syuzai_name]
                for i,row in extract_parlar_name_df.iterrows():
                    input_pledge_text += f'・{row["店舗名"]}\n'
                    
        # if len(extract_pledge_name_df ) != 0:
        #     # print('\n■',baitai,sep='')
        #     winput_pledge_text += '<h3>' + string_date_only + ' ' + todoufuken_kanji + ' スロット ' + baitai + '</h3>' + f'\n<img src="http://slotana777.com/wp-content/uploads/2021/04/{error_baitai}.jpg" alt="{error_baitai} タイトル画像" width="1000" height="400" class="alignnone size-full " />\n'
        # else:
        #     pass
        #break
    print(input_pledge_text)
# Out:
# Not found: ダブルジャッジ http://slotana777.com/wp-content/uploads/2023/04/%E3%83%80%E3%83%96%E3%83%AB%E3%82%B8%E3%83%A3%E3%83%83%E3%82%B8.jpg
# Not found: りゅーこ http://slotana777.com/wp-content/uploads/2023/04/%E3%82%8A%E3%82%85%E3%83%BC%E3%81%93.jpg
# Not found: あかだ主任のガチンコ… http://slotana777.com/wp-content/uploads/2023/04/%E3%81%82%E3%81%8B%E3%81%A0%E4%B8%BB%E4%BB%BB%E3%81%AE%E3%82%AC%E3%83%81%E3%83%B3%E3%82%B3%E2%80%A6.jpg
# Not found: DMMぱちタウン http://slotana777.com/wp-content/uploads/2023/04/DMM%E3%81%B1%E3%81%A1%E3%82%BF%E3%82%A6%E3%83%B3.jpg
# Not found: 旧イベ http://slotana777.com/wp-content/uploads/2023/04/%E6%97%A7%E3%82%A4%E3%83%99.jpg
# Not found: リニューアルオープン http://slotana777.com/wp-content/uploads/2023/04/%E3%83%AA%E3%83%8B%E3%83%A5%E3%83%BC%E3%82%A2%E3%83%AB%E3%82%AA%E3%83%BC%E3%83%97%E3%83%B3.jpg
# Not found: 新台入替 http://slotana777.com/wp-content/uploads/2023/04/%E6%96%B0%E5%8F%B0%E5%85%A5%E6%9B%BF.jpg
#
# <div class="box-alert box-alert-info">
# <i class="fas fa-exclamation-circle fa-4x"></i>
# <div class="alert-message">
#     <div class="alert-title">ダブルジャッジ</div>
#     <p>4月3日(月)  愛知県</p>
# </div></div><h4>ダブジャクエスト(初)</h4>
# ・メガコンコルド800春日井店+
# ・メガコンコルド1111BLAZE店
#
# <div class="box-alert box-alert-info">
# <i class="fas fa-exclamation-circle fa-4x"></i>
# <div class="alert-message">
#     <div class="alert-title">りゅーこ</div>
#     <p>4月3日(月)  愛知県</p>
# </div></div><h4>超りゅーこ広告</h4>
# ・コンコルド880愛西日比野駅前店
# <h4>りゅーこ広告</h4>
# ・ラッキープラザ1111弥富店
#
# <div class="box-alert box-alert-info">
# <i class="fas fa-exclamation-circle fa-4x"></i>
# <div class="alert-message">
#     <div class="alert-title">あかだ主任のガチンコ…</div>
#     <p>4月3日(月)  愛知県</p>
# </div></div><h4>ズバスロ</h4>
# ・メガコンコルド1020刈谷知立店
# <h4>ブラックサンダーG&</h4>
# ・G&L一宮店
# <img src="http://slotana777.com/wp-content/uploads/2023/04/その他取材・企画.jpg" alt="その他取材・企画" width="1000" height="400" class="size-full " />
# <h4>てんぴー来店</h4>
# ・M&K岡崎店
# <h4>スロパチなごや嬢すみれ来店</h4>
# ・G&L一宮店
# <h4>右京来店</h4>
# ・G&L一宮店
# <h4>エース小吉来店</h4>
# ・ダイマル星崎店
#
# <div class="box-alert box-alert-info">
# <i class="fas fa-exclamation-circle fa-4x"></i>
# <div class="alert-message">
#     <div class="alert-title">DMMぱちタウン</div>
#     <p>4月3日(月)  愛知県</p>
# </div></div><h4>THE新台入替</h4>
# ・GOLD 玉越 本店
#
# <div class="box-alert box-alert-info">
# <i class="fas fa-exclamation-circle fa-4x"></i>
# <div class="alert-message">
#     <div class="alert-title">旧イベ</div>
#     <p>4月3日(月)  愛知県</p>
# </div></div><h4>旧イベ(月と重なる日)</h4>
# ・マルハン新守山駅前店
# <h4>旧イベ(4のつく日)</h4>
# ・名宝刈谷店
# ・ミカドWORLD店
# ・名宝大清水店
# ・名宝岡崎店
#
# <div class="box-alert box-alert-info">
# <i class="fas fa-exclamation-circle fa-4x"></i>
# <div class="alert-message">
#     <div class="alert-title">リニューアルオープン</div>
#     <p>4月3日(月)  愛知県</p>
# </div></div><h4>リニューアル(2日目)</h4>
# ・ラッキープラザ1111弥富店
# ・メガガイア一宮
#
# <div class="box-alert box-alert-info">
# <i class="fas fa-exclamation-circle fa-4x"></i>
# <div class="alert-message">
#     <div class="alert-title">新台入替</div>
#     <p>4月3日(月)  愛知県</p>
# </div></div><h4>新台入替(P-WORLD引用)</h4>
# ・MEGAコンコルド豊川インター店
# ・メガコンコルド1220みなと23号通り店
# <img src="http://slotana777.com/wp-content/uploads/2023/04/未調査.jpg" alt="未調査" width="1000" height="400" class="size-full " />
# <h4>寿司投げ</h4>
# ・メガコンコルド800春日井店+

# %%
import requests
from time import sleep
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException
from bs4 import BeautifulSoup
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
import datetime
import time
import unicodedata
import string
import urllib
def removal_text(text):
    text = unicodedata.normalize("NFKC", text)
    text = text.translate(str.maketrans( '', '',string.punctuation  + '！'+ '　'+ ' '+'・'+'～' + '‐'))
    return text
def post_line_text(message,token):
    url = "https://notify-api.line.me/api/notify"
    headers = {"Authorization" : "Bearer "+ token}
    payload = {"message" :  message}
    post = requests.post(url ,headers = headers ,params=payload)
def post_line_text_and_image(message,image_path,token):
    url = "https://notify-api.line.me/api/notify"
    headers = {"Authorization" : "Bearer "+ token}
    payload = {"message" :  message}
    #imagesフォルダの中のgazo.jpg
    print('image_path',image_path)
    files = {"imageFile":open(image_path,'rb')}
    post = requests.post(url ,headers = headers ,params=payload,files=files)
def TablePlot(df,outputPath,w,h,fontsize,title):
    plt.rcParams["font.size"] = fontsize
    plt.rcParams["font.weight"] = "bold"
    fig, ax = plt.subplots(figsize=(w,h))
    ax.axis('off')
    ax.table(cellText=df.values,
             colLabels=df.columns,
             loc='center',
             bbox=[0,0,1,1])
    ax.set_title(f'{title}',
             fontweight ="bold")
    plt.savefig(outputPath)
cols = ['機種名', '台番号', 'G数', '差枚', 'BB', 'RB', 'ART', 'BB確率', 'RB確率', 'ART確率','合成確率','店舗名']
ichiran_all_tennpo_df = pd.DataFrame(index=[], columns=cols)
yesterday = datetime.date.today() + datetime.timedelta(days=-1)
browser = webdriver.Chrome(ChromeDriverManager().install())
todouhuken = '佐賀県'
todouhuken_url = urllib.parse.quote(todouhuken)
url = f'https://ana-slo.com/%e3%83%9b%e3%83%bc%e3%83%ab%e3%83%87%e3%83%bc%e3%82%bf/{todouhuken_url}'
browser.get(url)
html = browser.page_source.encode('utf-8')
soup = BeautifulSoup(html, 'lxml')
#print(tenpo_ichiran_df['ホール名'])
cols = ['機種名', '台番号', 'G数', '差枚', 'BB', 'RB', 'ART', 'BB確率', 'RB確率', 'ART確率','合成確率','店舗名']
ichiran_all_tennpo_df = pd.DataFrame(index=[], columns=cols)
prefecture = '宮崎県'
yesterday = datetime.date.today() + datetime.timedelta(days=-1)
browser = webdriver.Chrome(ChromeDriverManager().install())
url = f'https://ana-slo.com/%E3%83%9B%E3%83%BC%E3%83%AB%E3%83%87%E3%83%BC%E3%82%BF/{prefecture}/'
browser.get(url)
html = browser.page_source.encode('utf-8')
soup = BeautifulSoup(html, 'lxml')
parlar_name_parlar_url_dict = {}
for element in soup.find(class_="dataTable no-footer").find_all("a"):
    #print(element.string,element['href'])
    parlar_name = element.string
    parlar_name_url = element['href']
    parlar_name_parlar_url_dict[parlar_name] = parlar_name_url
#parlar_name_parlar_url_dict
#print(tenpo_ichiran_df['ホール名'])
i = 0
for parlar_name,palar_url in parlar_name_parlar_url_dict.items():
    decode = parlar_name_parlar_url_dict[parlar_name].split('/')[-2]
    decode_parlar_name =urllib.parse.unquote(parlar_name_parlar_url_dict[parlar_name].split('/')[-2]).replace('-データ一覧','')
    print(decode_parlar_name)
    url = f"https://ana-slo.com/{yesterday.strftime('%Y-%m-%d')}-{parlar_name}-data/"
    print(url)
    browser.get(url)
    try:
        html = browser.page_source.encode('utf-8')
        dfs = pd.read_html(html)
        #display(tenpo_df)
        time.sleep(1)
        for df in  dfs:
        #print(df.columns)
            if '機種名' in list(df.columns):
                ichiran_df = df
                ichiran_df['店舗名'] = decode_parlar_name
                ichiran_df['機種名'] = ichiran_df['機種名'].map(removal_text)
                ichiran_all_tennpo_df =  pd.concat([ichiran_all_tennpo_df, ichiran_df])
                i += 1
                break
    except:
        continue
    if i > 2:
        break

# %%
import glob

files = glob.glob(r"image\pledge_image\*")
for file in files:
    print(file)
    image = Image.open(file)
    draw = ImageDraw.Draw(image)
    img_resized = image.resize((1000 ,400))
# ファイルを保存
    img_resized.save(file, quality=100)
# Out:
# image\pledge_image\ChiiiPS(チップス).png
# image\pledge_image\dorislo.png
# image\pledge_image\HIPPO.jpeg
# image\pledge_image\その他取材・企画.png
# image\pledge_image\オフミー.jpeg
