# %%
prefecture_list:list[str] = '''北海道・東北
関東
中部'''.split('\n')

# %%
from PIL import Image, ImageFilter,ImageFont,ImageDraw
img = Image.open(r'image\image_source\eva_banner.jpg')
w, h = img.size
font = ImageFont.truetype(r'font\NotoSerifJP-Black.otf', 114)
draw = ImageDraw.Draw(img)
prefecture_name:str ='都道府県別 取材一覧\n          はこちら'
draw.multiline_text(((w/2), (h/2)), prefecture_name, '#FFFFFF', font=font,anchor='mm')
prefecture_name = prefecture_name.replace('\n','')
img.save(fr'image\image_source\prefecture_images\eva_banner_{prefecture_name}.jpg')

# %%
from PIL import Image, ImageFilter,ImageFont,ImageDraw
for prefecture_name in prefecture_list:
    img = Image.open(r'image\image_source\eva_banner.jpg')
    w, h = img.size
    font = ImageFont.truetype(r'font\NotoSerifJP-Black.otf', 184)
    draw = ImageDraw.Draw(img)
    #prefecture_name:str ='都道府県別取材一覧\nはこちら'
    draw.text(((w/2), (h/2)), prefecture_name, '#FFFFFF', font=font,anchor='mm')
    img.save(fr'image\prefecture_image\prefecture_images\eva_banner_{prefecture_name}.jpg')

# %%
text =''
image_url_head_text:str =  f'http://slotana777.com/wp-content/uploads/2023/03/'
for i,prefecture_name in enumerate(prefecture_list):
    i += 1
    if i % 2!= 0:
        text += '<div class="clearfix responbox50 smart50"><div class="lbox"><p>'
        image_banner_link_text = image_url_head_text + f'eva_banner_{prefecture_name}.jpg'
        tag_link_text =f'https://slotana777.com/tag/{prefecture_name}/'
        text += f'''\n<a href="{tag_link_text}">\n<img src="{image_banner_link_text}" alt="{prefecture_name}_パチンコ・パチスロ_イベントリンク_バナー" class="alignnone size-full " /></a></p></div>\n'''
        print(i)
    
    else:
        text += '<div class="rbox"><p>'
        image_banner_link_text = image_url_head_text + f'eva_banner_{prefecture_name}.jpg'
        tag_link_text =f'https://slotana777.com/tag/{prefecture_name}/'
        text += f'''\n<a href="{tag_link_text}">\n<img src="{image_banner_link_text}" alt="{prefecture_name}_パチンコ・パチスロ_イベントリンク_バナー" class="alignnone size-full " /></a></p></div>\n'''
        
print(text)
# Out:
# 1
# 3
# 5
# 7
# <div class="clearfix responbox50 smart50"><div class="lbox"><p>
# <a href="https://slotana777.com/tag/北海道/">
# <img src="http://slotana777.com/wp-content/uploads/2023/03/eva_banner_北海道.jpg" alt="北海道_パチンコ・パチスロ_イベントリンク_バナー" class="alignnone size-full " /></a></p></div>
# <div class="rbox"><p>
# <a href="https://slotana777.com/tag/青森県/">
# <img src="http://slotana777.com/wp-content/uploads/2023/03/eva_banner_青森県.jpg" alt="青森県_パチンコ・パチスロ_イベントリンク_バナー" class="alignnone size-full " /></a></p></div>
# <div class="clearfix responbox50 smart50"><div class="lbox"><p>
# <a href="https://slotana777.com/tag/岩手県/">
# <img src="http://slotana777.com/wp-content/uploads/2023/03/eva_banner_岩手県.jpg" alt="岩手県_パチンコ・パチスロ_イベントリンク_バナー" class="alignnone size-full " /></a></p></div>
# <div class="rbox"><p>
# <a href="https://slotana777.com/tag/宮城県/">
# ...

# %%
import datetime
image_url_head_text:str = f'http://slotana777.com/wp-content/uploads/{datetime.datetime.now().strftime("%Y")}/{datetime.datetime.now().strftime("%m")}/'
for i,prefecture_name in enumrate(prefecture_list):
    image_banner_link_text = image_url_head_text + f'eva_banner_{prefecture_name}.jpg'
    tag_link_text =f'https://slotana777.com/tag/{prefecture_name}/'
    url_text = f'''\n<a href="{tag_link_text}">\n<img src="{image_banner_link_text}" alt="{prefecture_name}_パチンコ・パチスロ_イベントリンク_バナー" class="alignnone size-full " /></a>'''
    print(url_text)
# Out:
# <a href="https://slotana777.com/tag/北海道/">
# <img src="http://slotana777.com/wp-content/uploads/2023/03/eva_banner_北海道.jpg" alt="北海道_パチンコ・パチスロ_イベントリンク_バナー" class="alignnone size-full " /></a>
#
# <a href="https://slotana777.com/tag/青森県/">
# <img src="http://slotana777.com/wp-content/uploads/2023/03/eva_banner_青森県.jpg" alt="青森県_パチンコ・パチスロ_イベントリンク_バナー" class="alignnone size-full " /></a>
#
# <a href="https://slotana777.com/tag/岩手県/">
# <img src="http://slotana777.com/wp-content/uploads/2023/03/eva_banner_岩手県.jpg" alt="岩手県_パチンコ・パチスロ_イベントリンク_バナー" class="alignnone size-full " /></a>
#
# <a href="https://slotana777.com/tag/宮城県/">
# <img src="http://slotana777.com/wp-content/uploads/2023/03/eva_banner_宮城県.jpg" alt="宮城県_パチンコ・パチスロ_イベントリンク_バナー" class="alignnone size-full " /></a>
#
# <a href="https://slotana777.com/tag/秋田県/">
# <img src="http://slotana777.com/wp-content/uploads/2023/03/eva_banner